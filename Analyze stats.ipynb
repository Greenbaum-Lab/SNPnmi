# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
folder = r'C:\Data\HUJI\hgdp\mock\chr9/'
chr_name = 'chr9'
idepth = '.idepth.idepth'
imiss = '.imiss.imiss'
lmiss = '.lmiss.lmiss'
ldepth = '.ldepth.ldepth.mean'
lqual = '.lqual.lqual'

i_stats = [imiss, idepth]
l_stats = [lmiss, ldepth, lqual]

# %%
import pandas as pd

# %%
def get_stats(metric, col_name):
    df = pd.read_csv(folder+chr_name+metric, sep='\t')
    print('Min:',df[col_name].min(),'Max:',df[col_name].max())
    print('Mean:',df[col_name].mean(),'Std:',df[col_name].std())
    df[col_name].hist(bins=100)

# %%
#idepth - mean
col_name = 'MEAN_DEPTH'
get_stats(idepth, col_name)
# Out:
# Min: 20.4842 Max: 70.8474
# Mean: 33.73985791173305 Std: 5.048899576570471

# %%
#ldepth - mean
col_name = 'MEAN_DEPTH'
get_stats(ldepth, col_name)
# Out:
# Min: 0.734123 Max: 89.8654
# Mean: 33.739850556499135 Std: 6.8183876164549355

# %%
#ldepth var
col_name = 'VAR_DEPTH'
get_stats(ldepth, col_name)
# Out:
# Min: 1.9324700000000001 Max: 1290.99
# Mean: 85.6073239620777 Std: 62.53151406577807

# %%
#imiss
col_name = 'F_MISS'
get_stats(imiss, col_name)
# Out:
# Min: 0.0279659 Max: 0.194407
# Mean: 0.06038803186221743 Std: 0.01520635964234098

# %%
#lmiss
col_name = 'F_MISS'
get_stats(lmiss, col_name)
# Out:
# Min: 0.0 Max: 0.9989239999999999
# Mean: 0.060388029507302605 Std: 0.15472362252321098

# %%
#lqual
col_name = 'QUAL'
get_stats(lqual, col_name)
# Out:
# Min: 30.07 Max: 1445340.0
# Mean: 39949.589917639736 Std: 136764.0434668687
