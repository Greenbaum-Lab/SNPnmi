# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
df = pd.read_csv(r"C:\Data\HUJI\hgdp\hgdp_stats\split_vcf_output_stats.csv")
df

# %%
# run time (in days)
print('all:',df['run_time_in_seconds'].sum()/(60*60*24))
print('macs:',df[df['mac']=='-']['run_time_in_seconds'].sum()/(60*60*24))
print('mafs:',df[df['maf']=='-']['run_time_in_seconds'].sum()/(60*60*24))

# %%
num_ind = 929
min_mac = 2
max_mac = 18
min_maf = 1
max_maf = 49
min_chr = 1
max_chr = 22

# %%
# first validate all data is here
passed = True
for chr_i in range(min_chr, max_chr+1):
    for mac in range(min_mac, max_mac+1):
        if len(df[(df['chr_name_name'] == f'chr{chr_i}') & (df['mac'] == f'{mac}')])!=1:
            passed = False
            print(f'missing chr{chr_i}, mac {mac}')
    for maf in range(min_maf, max_maf+1):
        if len(df[(df['chr_name_name'] == f'chr{chr_i}') & (df['maf'] == f'{maf*1.0/100}')])!=1:
            passed = False
            print(f'missing chr{chr_i}, maf {maf}')
assert passed
print(f'PASSED - all chrs has all relevant macs and mafs')

# %%
# next validate all have the correct num_ind
passed = True
for c  in ['num_of_indv_after_filter','indv_num_of_lines','012_num_of_lines','num_of_possible_indv']:
    if len(df[df[c]!=num_ind])!=0:
        passed =False
        print(f'wrong number of ind for column {c}')
        print(df[df[c]!=num_ind][['chr_name_name',c]])
assert passed
print(f'PASSED - all entries has the correct num of individuals ({num_ind})')

# %%
# next validate same num_of_possible_sites per chr
grouped = df.groupby('chr_name_name')['num_of_possible_sites'].agg('nunique').reset_index()
cond = len(grouped[grouped['num_of_possible_sites']!=1])==0
if not cond:
    print(f'a chr with different number of num_of_possible_sites is found')
    print(grouped[grouped['num_of_possible_sites']!=1])
    assert cond
else:
    print('PASSED - all chrs has the same number of possilbe sites')

# %%
# validate the number of sites after filtring is indeed the number of sites in the 012 file
df['validate012sites'] = (df['num_of_sites_after_filter'] == df['pos_num_of_lines']) & \
                         (df['num_of_sites_after_filter'] == df['012_min_num_of_sites']) & \
                         (df['num_of_sites_after_filter'] == df['012_max_num_of_sites'])
cond =len(df[~df['validate012sites']])==0
if not cond:
    print(f'number of sites after filtring doesnt match 012 file')
    print(df[~df['validate012sites']])
    assert cond
else:
    print('PASSED - number of sites in 012 files matches that of vcftools output')

# %%
# validate per chr and class we have a single line
chr_class_df = df.groupby(['chr_name_name','mac_or_maf'])['mac'].count().reset_index()
assert(len(chr_class_df[chr_class_df['mac']!=1])==0)
print('PASSED - single line per chr and name')

# %%
# per class:
classes_sum = df.groupby('mac_or_maf')['num_of_sites_after_filter'].agg('sum').reset_index()
classes_sum['num_of_sites_after_filter'].sum()
# 1. clean exact maf upper limit
# 2. inital comparison using all sites in class (without subsample)
# 3. windows sampled across genom (and not same chr)
# 4. windows of 100 - ~320K windows
# 5. subsample size - 10k done 100, [next step - ideally(1000)] times
# min class 93920
# max class 7303147

# %% [markdown]
# # Prepare windows

# %%
import os
import json 
import pandas as pd
import random
random.seed(a='42', version=2)


def validate_split_vcf_output_stats_file(split_vcf_output_stats_file, num_ind, min_mac, max_mac, min_maf, max_maf, min_chr, max_chr):
    df = pd.read_csv(split_vcf_output_stats_file)
    df['mac_or_maf'] = df.apply(lambda r : r['mac'] if r['mac']!='-' else r['maf'], axis=1)

    # first validate all data is here
    passed = True
    for chr_i in range(min_chr, max_chr+1):
        for mac in range(min_mac, max_mac+1):
            count = len(df[(df['chr_name_name'] == f'chr{chr_i}') & (df['mac'] == f'{mac}')])
            if count != 1:
                passed = False
                print(f'chr{chr_i}, mac {mac} appears {count} times')
        for maf in range(min_maf, max_maf+1):
            count = len(df[(df['chr_name_name'] == f'chr{chr_i}') & (df['maf'] == f'{maf*1.0/100}')])
            if count!=1:
                passed = False
                print(f'chr{chr_i}, mac {mac} appears {count} times')
    assert passed
    print(f'PASSED - all chrs has all relevant macs and mafs once')  

    # next validate all have the correct num_ind
    passed = True
    for c  in ['num_of_indv_after_filter','indv_num_of_lines','012_num_of_lines','num_of_possible_indv']:
        if len(df[df[c]!=num_ind])!=0:
            passed =False
            print(f'wrong number of ind for column {c}')
            print(df[df[c]!=num_ind][['chr_name_name',c]])
    assert passed
    print(f'PASSED - all entries has the correct num of individuals ({num_ind})')

    # next validate same num_of_possible_sites per chr
    grouped = df.groupby('chr_name_name')['num_of_possible_sites'].agg('nunique').reset_index()
    cond = len(grouped[grouped['num_of_possible_sites']!=1])==0
    if not cond:
        print(f'a chr with different number of num_of_possible_sites is found')
        print(grouped[grouped['num_of_possible_sites']!=1])
        assert cond
    else:
        print('PASSED - all chrs has the same number of possilbe sites')

    # validate the number of sites after filtring is indeed the number of sites in the 012 file
    df['validate012sites'] = (df['num_of_sites_after_filter'] == df['pos_num_of_lines']) & \
                             (df['num_of_sites_after_filter'] == df['012_min_num_of_sites']) & \
                             (df['num_of_sites_after_filter'] == df['012_max_num_of_sites'])
    cond =len(df[~df['validate012sites']])==0
    if not cond:
        print(f'number of sites after filtring doesnt match 012 file')
        print(df[~df['validate012sites']])
        assert cond
    else:
        print('PASSED - number of sites in 012 files matches that of vcftools output')

    # validate per chr and class we have a single line
    chr_class_df = df.groupby(['chr_name_name','mac_or_maf'])['mac'].count().reset_index()
    assert(len(chr_class_df[chr_class_df['mac']!=1])==0)
    print('PASSED - single line per chr and name')


def get_class2sites(split_vcf_output_stats_file):
    # per class, we generate a shuffled list of sites (chr and index(!) not site name)
    # given a window size we split the shuffled list to windows of approximatly this size
    df = pd.read_csv(split_vcf_output_stats_file)
    df['mac_or_maf'] = df.apply(lambda r : r['mac'] if r['mac']!='-' else r['maf'], axis=1)
    class2sites = dict()
    for c in df['mac_or_maf'].unique():
        print('Prepare indexes for class',c)
        all_class_indexes = []
        for i,r in df[df['mac_or_maf']==c].iterrows():
            chr_n = r['chr_name_name'][3:]
            num_sites = r['num_of_sites_after_filter']
            all_class_indexes = all_class_indexes + [f'{chr_n};{i}' for i in range(num_sites)]
        print('List is ready, size is:', len(all_class_indexes),'. Shuffle the list')
        random.shuffle(all_class_indexes)
        class2sites[c] = all_class_indexes
        print('Done with class',c)
        print()
        
    return class2sites

# given a window size and a(shuffled) list of tuples of chr id and index, we split the list to windows, and sort each by chr id, to make the reading of it easy
# assuming win_size=100:
# 1. get modulu (for sure smallar than 100)
# 2. check int divesion (num_windows)
# 3. as we know the minimum class has 93920 elements, we know that num_windows > modulu
# so, in the last <module> windows, add 1
def get_windows_sizes(list_size, win_size=100):
    assert list_size>9900
    mod = list_size%win_size
    num_wid = int(list_size/win_size)
    num_win_exact_win_size = num_wid-mod
    assert num_win_exact_win_size>0
    assert (num_win_exact_win_size*win_size)+(mod*(win_size+1)) == list_size
    return num_win_exact_win_size, mod


def split_to_windows(all_class_indexes, window_size, output_file):
    num_win_desired_size, num_win_size_plus_one = get_windows_sizes(len(all_class_indexes), window_size)
    num_win_desired_size, num_win_size_plus_one
    print(f'{len(all_class_indexes)} to cover')
    print(f'{num_win_desired_size} windows of size {window_size}')
    print(f'{num_win_size_plus_one} windows of size {window_size+1}')
    total_num_of_windows = num_win_desired_size + num_win_size_plus_one
    print(f'{total_num_of_windows} total_num_of_windows')
    # this will be a list of windows
    windows = []
    covered=0
    for i in range(num_win_desired_size):
        # todo - not sure about the sort - this will group by chr, but not internaly sort by index
        window = all_class_indexes[covered:covered+window_size]
        window.sort()
        covered+=window_size
        windows.append(window)
    for i in range(num_win_size_plus_one):
        # todo - not sure about the sort
        window = all_class_indexes[covered:covered+(window_size+1)]
        window.sort()
        covered+=window_size+1
        windows.append(window)
    print(f'{covered} covered')
    assert covered==len(all_class_indexes)
    total_length = 0
    for w in windows:
        total_length+=len(w)
    assert total_length==covered

    with open(output_file, "w" ) as f: 
        json.dump(windows, f )
    return total_num_of_windows

def build_windows_indexes_files(split_vcf_output_stats_file,window_size,output_folder, num_ind, min_mac, max_mac, min_maf, max_maf, min_chr, max_chr):
    validate_split_vcf_output_stats_file(split_vcf_output_stats_file, num_ind, min_mac, max_mac, min_maf, max_maf, min_chr, max_chr)
    class2sites = get_class2sites(split_vcf_output_stats_file)
    os.makedirs(output_folder, exist_ok=True)
    for c, class_indexes in class2sites.items():
        print(f'Generate windows indexes file for class {c}')
        output_file=output_folder+'windows_indexes_for_class_'+c+'.json'
        total_num_of_windows = split_to_windows(class_indexes, window_size, output_file)
        with open(output_folder+'number_of_windows_per_class.txt','a+') as f:
            f.write(f'{c} {total_num_of_windows}\n')

# %%
output_folder='./windows/'

window_size=100
split_vcf_output_stats_file = r"C:\Data\HUJI\hgdp\hgdp_stats\split_vcf_output_stats.csv"
num_ind = 929
min_mac = 2
max_mac = 18
min_maf = 1
max_maf = 48 # TODO 49
min_chr = 1
max_chr = 22
build_windows_indexes_files(split_vcf_output_stats_file,window_size,output_folder, num_ind, min_mac, max_mac, min_maf, max_maf, min_chr, max_chr)
# Out:
# PASSED - all chrs has all relevant macs and mafs once
# PASSED - all entries has the correct num of individuals (929)
# PASSED - all chrs has the same number of possilbe sites
# PASSED - number of sites in 012 files matches that of vcftools output
# PASSED - single line per chr and name
# Prepare indexes for class 2
# List is ready, size is: 7303147 . Shuffle the list
# Done with class 2
#
# Prepare indexes for class 3
# List is ready, size is: 3761755 . Shuffle the list
# Done with class 3
#
# Prepare indexes for class 4
# List is ready, size is: 2386298 . Shuffle the list
# Done with class 4
#
# Prepare indexes for class 5
# List is ready, size is: 1681647 . Shuffle the list
# Done with class 5
#
# Prepare indexes for class 6
# List is ready, size is: 1256167 . Shuffle the list
# Done with class 6
#
# Prepare indexes for class 7
# List is ready, size is: 990881 . Shuffle the list
# Done with class 7
#
# Prepare indexes for class 8
# List is ready, size is: 806359 . Shuffle the list
# Done with class 8
#
# Prepare indexes for class 9
# List is ready, size is: 660205 . Shuffle the list
# Done with class 9
#
# Prepare indexes for class 10
# List is ready, size is: 560278 . Shuffle the list
# Done with class 10
#
# Prepare indexes for class 11
# List is ready, size is: 479642 . Shuffle the list
# Done with class 11
#
# Prepare indexes for class 12
# List is ready, size is: 418830 . Shuffle the list
# Done with class 12
#
# Prepare indexes for class 13
# List is ready, size is: 368255 . Shuffle the list
# Done with class 13
#
# Prepare indexes for class 14
# List is ready, size is: 328620 . Shuffle the list
# Done with class 14
#
# Prepare indexes for class 15
# List is ready, size is: 294825 . Shuffle the list
# Done with class 15
#
# Prepare indexes for class 16
# List is ready, size is: 264812 . Shuffle the list
# Done with class 16
#
# Prepare indexes for class 17
# List is ready, size is: 243008 . Shuffle the list
# Done with class 17
#
# Prepare indexes for class 18
# List is ready, size is: 218855 . Shuffle the list
# Done with class 18
#
# Prepare indexes for class 0.01
# List is ready, size is: 2204387 . Shuffle the list
# Done with class 0.01
#
# Prepare indexes for class 0.02
# List is ready, size is: 888789 . Shuffle the list
# Done with class 0.02
#
# Prepare indexes for class 0.03
# List is ready, size is: 561345 . Shuffle the list
# Done with class 0.03
#
# Prepare indexes for class 0.04
# List is ready, size is: 397547 . Shuffle the list
# Done with class 0.04
#
# Prepare indexes for class 0.05
# List is ready, size is: 336815 . Shuffle the list
# Done with class 0.05
#
# Prepare indexes for class 0.06
# List is ready, size is: 280452 . Shuffle the list
# Done with class 0.06
#
# Prepare indexes for class 0.07
# List is ready, size is: 252305 . Shuffle the list
# Done with class 0.07
#
# Prepare indexes for class 0.08
# List is ready, size is: 234156 . Shuffle the list
# Done with class 0.08
#
# Prepare indexes for class 0.09
# List is ready, size is: 215391 . Shuffle the list
# Done with class 0.09
#
# Prepare indexes for class 0.1
# List is ready, size is: 200144 . Shuffle the list
# Done with class 0.1
#
# Prepare indexes for class 0.11
# List is ready, size is: 188785 . Shuffle the list
# Done with class 0.11
#
# Prepare indexes for class 0.12
# List is ready, size is: 182253 . Shuffle the list
# Done with class 0.12
#
# Prepare indexes for class 0.13
# List is ready, size is: 170652 . Shuffle the list
# Done with class 0.13
#
# Prepare indexes for class 0.14
# List is ready, size is: 165726 . Shuffle the list
# Done with class 0.14
#
# Prepare indexes for class 0.15
# List is ready, size is: 158194 . Shuffle the list
# Done with class 0.15
#
# Prepare indexes for class 0.16
# List is ready, size is: 154359 . Shuffle the list
# Done with class 0.16
#
# Prepare indexes for class 0.17
# List is ready, size is: 149326 . Shuffle the list
# Done with class 0.17
#
# Prepare indexes for class 0.18
# List is ready, size is: 143159 . Shuffle the list
# Done with class 0.18
#
# Prepare indexes for class 0.19
# List is ready, size is: 139531 . Shuffle the list
# Done with class 0.19
#
# Prepare indexes for class 0.2
# List is ready, size is: 132578 . Shuffle the list
# Done with class 0.2
#
# Prepare indexes for class 0.21
# List is ready, size is: 131792 . Shuffle the list
# Done with class 0.21
#
# Prepare indexes for class 0.22
# List is ready, size is: 128865 . Shuffle the list
# Done with class 0.22
#
# Prepare indexes for class 0.23
# List is ready, size is: 123479 . Shuffle the list
# Done with class 0.23
#
# Prepare indexes for class 0.24
# List is ready, size is: 121415 . Shuffle the list
# Done with class 0.24
#
# Prepare indexes for class 0.25
# List is ready, size is: 122463 . Shuffle the list
# Done with class 0.25
#
# Prepare indexes for class 0.26
# List is ready, size is: 117064 . Shuffle the list
# Done with class 0.26
#
# Prepare indexes for class 0.27
# List is ready, size is: 114043 . Shuffle the list
# Done with class 0.27
#
# Prepare indexes for class 0.28
# List is ready, size is: 112633 . Shuffle the list
# Done with class 0.28
#
# Prepare indexes for class 0.29
# List is ready, size is: 112108 . Shuffle the list
# Done with class 0.29
#
# Prepare indexes for class 0.3
# List is ready, size is: 108355 . Shuffle the list
# Done with class 0.3
#
# Prepare indexes for class 0.31
# List is ready, size is: 106599 . Shuffle the list
# Done with class 0.31
#
# Prepare indexes for class 0.32
# List is ready, size is: 106809 . Shuffle the list
# Done with class 0.32
#
# Prepare indexes for class 0.33
# List is ready, size is: 105372 . Shuffle the list
# Done with class 0.33
#
# Prepare indexes for class 0.34
# List is ready, size is: 104681 . Shuffle the list
# Done with class 0.34
#
# Prepare indexes for class 0.35
# List is ready, size is: 101891 . Shuffle the list
# Done with class 0.35
#
# Prepare indexes for class 0.36
# List is ready, size is: 100203 . Shuffle the list
# Done with class 0.36
#
# Prepare indexes for class 0.37
# List is ready, size is: 102537 . Shuffle the list
# Done with class 0.37
#
# Prepare indexes for class 0.38
# List is ready, size is: 100795 . Shuffle the list
# Done with class 0.38
#
# Prepare indexes for class 0.39
# List is ready, size is: 98721 . Shuffle the list
# Done with class 0.39
#
# Prepare indexes for class 0.4
# List is ready, size is: 99445 . Shuffle the list
# Done with class 0.4
#
# Prepare indexes for class 0.41
# List is ready, size is: 97672 . Shuffle the list
# Done with class 0.41
#
# Prepare indexes for class 0.42
# List is ready, size is: 100586 . Shuffle the list
# Done with class 0.42
#
# Prepare indexes for class 0.43
# List is ready, size is: 97068 . Shuffle the list
# Done with class 0.43
#
# Prepare indexes for class 0.44
# List is ready, size is: 97413 . Shuffle the list
# Done with class 0.44
#
# Prepare indexes for class 0.45
# List is ready, size is: 93920 . Shuffle the list
# Done with class 0.45
#
# Prepare indexes for class 0.46
# List is ready, size is: 94839 . Shuffle the list
# Done with class 0.46
#
# Prepare indexes for class 0.47
# List is ready, size is: 96021 . Shuffle the list
# Done with class 0.47
#
# Prepare indexes for class 0.48
# List is ready, size is: 98227 . Shuffle the list
# Done with class 0.48
#
# Generate windows indexes file for class 2
# 7303147 to cover
# 72984 windows of size 100
# 47 windows of size 101
# 73031 total_num_of_windows
# 7303147 covered
# Generate windows indexes file for class 3
# 3761755 to cover
# 37562 windows of size 100
# 55 windows of size 101
# 37617 total_num_of_windows
# 3761755 covered
# Generate windows indexes file for class 4
# 2386298 to cover
# 23764 windows of size 100
# 98 windows of size 101
# 23862 total_num_of_windows
# 2386298 covered
# Generate windows indexes file for class 5
# 1681647 to cover
# 16769 windows of size 100
# 47 windows of size 101
# 16816 total_num_of_windows
# 1681647 covered
# Generate windows indexes file for class 6
# 1256167 to cover
# 12494 windows of size 100
# 67 windows of size 101
# 12561 total_num_of_windows
# 1256167 covered
# Generate windows indexes file for class 7
# 990881 to cover
# 9827 windows of size 100
# 81 windows of size 101
# 9908 total_num_of_windows
# 990881 covered
# Generate windows indexes file for class 8
# 806359 to cover
# 8004 windows of size 100
# 59 windows of size 101
# 8063 total_num_of_windows
# 806359 covered
# Generate windows indexes file for class 9
# 660205 to cover
# 6597 windows of size 100
# 5 windows of size 101
# 6602 total_num_of_windows
# 660205 covered
# Generate windows indexes file for class 10
# 560278 to cover
# 5524 windows of size 100
# 78 windows of size 101
# 5602 total_num_of_windows
# 560278 covered
# Generate windows indexes file for class 11
# 479642 to cover
# 4754 windows of size 100
# 42 windows of size 101
# 4796 total_num_of_windows
# 479642 covered
# Generate windows indexes file for class 12
# 418830 to cover
# 4158 windows of size 100
# 30 windows of size 101
# 4188 total_num_of_windows
# 418830 covered
# Generate windows indexes file for class 13
# 368255 to cover
# 3627 windows of size 100
# 55 windows of size 101
# 3682 total_num_of_windows
# 368255 covered
# Generate windows indexes file for class 14
# 328620 to cover
# 3266 windows of size 100
# 20 windows of size 101
# 3286 total_num_of_windows
# 328620 covered
# Generate windows indexes file for class 15
# 294825 to cover
# 2923 windows of size 100
# 25 windows of size 101
# 2948 total_num_of_windows
# 294825 covered
# Generate windows indexes file for class 16
# 264812 to cover
# 2636 windows of size 100
# 12 windows of size 101
# 2648 total_num_of_windows
# 264812 covered
# Generate windows indexes file for class 17
# 243008 to cover
# 2422 windows of size 100
# 8 windows of size 101
# 2430 total_num_of_windows
# 243008 covered
# Generate windows indexes file for class 18
# 218855 to cover
# 2133 windows of size 100
# 55 windows of size 101
# 2188 total_num_of_windows
# 218855 covered
# Generate windows indexes file for class 0.01
# 2204387 to cover
# 21956 windows of size 100
# 87 windows of size 101
# 22043 total_num_of_windows
# 2204387 covered
# Generate windows indexes file for class 0.02
# 888789 to cover
# 8798 windows of size 100
# 89 windows of size 101
# 8887 total_num_of_windows
# 888789 covered
# Generate windows indexes file for class 0.03
# 561345 to cover
# 5568 windows of size 100
# 45 windows of size 101
# 5613 total_num_of_windows
# 561345 covered
# Generate windows indexes file for class 0.04
# 397547 to cover
# 3928 windows of size 100
# 47 windows of size 101
# 3975 total_num_of_windows
# 397547 covered
# Generate windows indexes file for class 0.05
# 336815 to cover
# 3353 windows of size 100
# 15 windows of size 101
# 3368 total_num_of_windows
# 336815 covered
# Generate windows indexes file for class 0.06
# 280452 to cover
# 2752 windows of size 100
# 52 windows of size 101
# 2804 total_num_of_windows
# 280452 covered
# Generate windows indexes file for class 0.07
# 252305 to cover
# 2518 windows of size 100
# 5 windows of size 101
# 2523 total_num_of_windows
# 252305 covered
# Generate windows indexes file for class 0.08
# 234156 to cover
# 2285 windows of size 100
# 56 windows of size 101
# 2341 total_num_of_windows
# 234156 covered
# Generate windows indexes file for class 0.09
# 215391 to cover
# 2062 windows of size 100
# 91 windows of size 101
# 2153 total_num_of_windows
# 215391 covered
# Generate windows indexes file for class 0.1
# 200144 to cover
# 1957 windows of size 100
# 44 windows of size 101
# 2001 total_num_of_windows
# 200144 covered
# Generate windows indexes file for class 0.11
# 188785 to cover
# 1802 windows of size 100
# 85 windows of size 101
# 1887 total_num_of_windows
# 188785 covered
# Generate windows indexes file for class 0.12
# 182253 to cover
# 1769 windows of size 100
# 53 windows of size 101
# 1822 total_num_of_windows
# 182253 covered
# Generate windows indexes file for class 0.13
# 170652 to cover
# 1654 windows of size 100
# 52 windows of size 101
# 1706 total_num_of_windows
# 170652 covered
# Generate windows indexes file for class 0.14
# 165726 to cover
# 1631 windows of size 100
# 26 windows of size 101
# 1657 total_num_of_windows
# 165726 covered
# Generate windows indexes file for class 0.15
# 158194 to cover
# 1487 windows of size 100
# 94 windows of size 101
# 1581 total_num_of_windows
# 158194 covered
# Generate windows indexes file for class 0.16
# 154359 to cover
# 1484 windows of size 100
# 59 windows of size 101
# 1543 total_num_of_windows
# 154359 covered
# Generate windows indexes file for class 0.17
# 149326 to cover
# 1467 windows of size 100
# 26 windows of size 101
# 1493 total_num_of_windows
# 149326 covered
# Generate windows indexes file for class 0.18
# 143159 to cover
# 1372 windows of size 100
# 59 windows of size 101
# 1431 total_num_of_windows
# 143159 covered
# Generate windows indexes file for class 0.19
# 139531 to cover
# 1364 windows of size 100
# 31 windows of size 101
# 1395 total_num_of_windows
# 139531 covered
# Generate windows indexes file for class 0.2
# 132578 to cover
# 1247 windows of size 100
# 78 windows of size 101
# 1325 total_num_of_windows
# 132578 covered
# Generate windows indexes file for class 0.21
# 131792 to cover
# 1225 windows of size 100
# 92 windows of size 101
# 1317 total_num_of_windows
# 131792 covered
# Generate windows indexes file for class 0.22
# 128865 to cover
# 1223 windows of size 100
# 65 windows of size 101
# 1288 total_num_of_windows
# 128865 covered
# Generate windows indexes file for class 0.23
# 123479 to cover
# 1155 windows of size 100
# 79 windows of size 101
# 1234 total_num_of_windows
# 123479 covered
# Generate windows indexes file for class 0.24
# 121415 to cover
# 1199 windows of size 100
# 15 windows of size 101
# 1214 total_num_of_windows
# 121415 covered
# Generate windows indexes file for class 0.25
# 122463 to cover
# 1161 windows of size 100
# 63 windows of size 101
# 1224 total_num_of_windows
# 122463 covered
# Generate windows indexes file for class 0.26
# 117064 to cover
# 1106 windows of size 100
# 64 windows of size 101
# 1170 total_num_of_windows
# 117064 covered
# Generate windows indexes file for class 0.27
# 114043 to cover
# 1097 windows of size 100
# 43 windows of size 101
# 1140 total_num_of_windows
# 114043 covered
# Generate windows indexes file for class 0.28
# 112633 to cover
# 1093 windows of size 100
# 33 windows of size 101
# 1126 total_num_of_windows
# 112633 covered
# Generate windows indexes file for class 0.29
# 112108 to cover
# 1113 windows of size 100
# 8 windows of size 101
# 1121 total_num_of_windows
# 112108 covered
# Generate windows indexes file for class 0.3
# 108355 to cover
# 1028 windows of size 100
# 55 windows of size 101
# 1083 total_num_of_windows
# 108355 covered
# Generate windows indexes file for class 0.31
# 106599 to cover
# 966 windows of size 100
# 99 windows of size 101
# 1065 total_num_of_windows
# 106599 covered
# Generate windows indexes file for class 0.32
# 106809 to cover
# 1059 windows of size 100
# 9 windows of size 101
# 1068 total_num_of_windows
# 106809 covered
# Generate windows indexes file for class 0.33
# 105372 to cover
# 981 windows of size 100
# 72 windows of size 101
# 1053 total_num_of_windows
# 105372 covered
# Generate windows indexes file for class 0.34
# 104681 to cover
# 965 windows of size 100
# 81 windows of size 101
# 1046 total_num_of_windows
# 104681 covered
# Generate windows indexes file for class 0.35
# 101891 to cover
# 927 windows of size 100
# 91 windows of size 101
# 1018 total_num_of_windows
# 101891 covered
# Generate windows indexes file for class 0.36
# 100203 to cover
# 999 windows of size 100
# 3 windows of size 101
# 1002 total_num_of_windows
# 100203 covered
# Generate windows indexes file for class 0.37
# 102537 to cover
# 988 windows of size 100
# 37 windows of size 101
# 1025 total_num_of_windows
# 102537 covered
# Generate windows indexes file for class 0.38
# 100795 to cover
# 912 windows of size 100
# 95 windows of size 101
# 1007 total_num_of_windows
# 100795 covered
# Generate windows indexes file for class 0.39
# 98721 to cover
# 966 windows of size 100
# 21 windows of size 101
# 987 total_num_of_windows
# 98721 covered
# Generate windows indexes file for class 0.4
# 99445 to cover
# 949 windows of size 100
# 45 windows of size 101
# 994 total_num_of_windows
# 99445 covered
# Generate windows indexes file for class 0.41
# 97672 to cover
# 904 windows of size 100
# 72 windows of size 101
# 976 total_num_of_windows
# 97672 covered
# Generate windows indexes file for class 0.42
# 100586 to cover
# 919 windows of size 100
# 86 windows of size 101
# 1005 total_num_of_windows
# 100586 covered
# Generate windows indexes file for class 0.43
# 97068 to cover
# 902 windows of size 100
# 68 windows of size 101
# 970 total_num_of_windows
# 97068 covered
# Generate windows indexes file for class 0.44
# 97413 to cover
# 961 windows of size 100
# 13 windows of size 101
# 974 total_num_of_windows
# 97413 covered
# Generate windows indexes file for class 0.45
# 93920 to cover
# 919 windows of size 100
# 20 windows of size 101
# 939 total_num_of_windows
# 93920 covered
# Generate windows indexes file for class 0.46
# 94839 to cover
# 909 windows of size 100
# 39 windows of size 101
# 948 total_num_of_windows
# 94839 covered
# Generate windows indexes file for class 0.47
# 96021 to cover
# 939 windows of size 100
# 21 windows of size 101
# 960 total_num_of_windows
# 96021 covered
# Generate windows indexes file for class 0.48
# 98227 to cover
# 955 windows of size 100
# 27 windows of size 101
# 982 total_num_of_windows
# 98227 covered

# %%
# we can use the number_of_windows_per_class file in bash to know how many jobs to schedule
# we will need to load the window indexes file in bash, split it, and for each window submit a job (we dont have the number of windows per class)
# load windows_indexes_file
with open(output_file, "r" ) as f: 
    windows = json.load(f)
