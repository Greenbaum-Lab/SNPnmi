# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from utils.config import *
local_data_folder = get_local_data_folder('hgdp')
local_data_folder
# Out:
# 'C:/Data/HUJI/hgdp/'

# %%
# todo - think about the infra to get to each file, and naming conventions

# %% [markdown]
# # Process 012 files

# %%
#imports and consts
import os.path
import logging
import pandas as pd
import math

SUFFIX_POS = '.012.pos'
SUFFIX_012 = '.012'
OUTPUT_PATTERN_DIST_FILE = 'dist_slice_{slice_index}_{num_of_sites}_sites.tsv'
OUTPUT_PATTERN_SITES_FILE = 'sites_ids_slice_{slice_index}.tsv'
OUTPUT_PATTERN_LOG_FILE = 'Process012_{chr_name}_MAF_{maf}.log'

logger = logging.getLogger(__name__)

def _set_logger(chr_name, maf):
    log_file = OUTPUT_PATTERN_LOG_FILE.format(chr_name=chr_name, maf=maf)
    fhandler = logging.FileHandler(filename=log_file, mode='a')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    fhandler.setFormatter(formatter)
    # TODO - file is empty!
    logger.addHandler(fhandler)

def _log(msg, level=logging.INFO):
    print(msg)
    logger.log(level, msg)

# %%
# func params
path_to_012_files = 'C:\Data\HUJI\hgdp\mock\out'
base_output_path = 'C:\Data\HUJI\hgdp\mock'
# if not in range - will raise a warning
min_minor_freq_expected = 0.49
max_minor_freq_expected = 0.5
# if we have 91 sites, we may have a file with 1 sites in it (can be improved if we want..)
# TODO - validate with Gili
desired_num_of_sites_per_output = 10
# TODO - validate with Gili
# if we have less than this which are valied (not -1), site is not included in calc. This will change the 
min_valid_sites_precentage = 0.1

# %%
def _validate_file_exist(p):
    if not os.path.isfile(p):
        _log(f'Cant file file {p}', logging.ERROR)

# %%
def _get_chr_name(path_pos):
    with open(path_pos, 'r') as f:
        l = f.readline()
        char_name = l.split('\t')[0]
        return char_name

# %%
def _prepare_output_folder(base_output_path, chr_name):
    output_dir = f'{base_output_path}/{chr_name}/'
    _log(f'output_dir is {output_dir}')
    os.makedirs(output_dir, exist_ok=True)
    return output_dir

# %%
def _build_pairwise_db(n, v):
    return [[v]*(n-i) for i in range (1,n)]

# %%
def _slice_calc_pairwise_distances_with_guardrails(slice_index, num_of_slices, slice_df, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected):
    # for each column, we calc the pairwise distances and add it to the grand total
    # for performance, we use 2 lists of lists, one for distances and one for counts
    slice_pairwise_counts = _build_pairwise_db(len(slice_df), 0)
    slice_pairwise_dist = _build_pairwise_db(len(slice_df), 0.0)
    for site_index in range(len(slice_df.columns)):
        _site_calc_pairwise_distances_with_guardrails(slice_index, num_of_slices, site_index, slice_df, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected, slice_pairwise_counts, slice_pairwise_dist)
    return slice_pairwise_counts, slice_pairwise_dist

# %%
def _site_calc_pairwise_distances(slice_index, num_of_slices, site_index, genotypes, num_individuals, ref_freq, non_ref_freq, slice_pairwise_counts, slice_pairwise_dist):
    for i1 in range(num_individuals-1):
        i1_val = genotypes[i1]
        # if this entry is not valid for i1, no need to go over all the others, nothing to add to freq nor counts
        if i1%100==0:
            _log(f'Slice: {slice_index}/{num_of_slices}. Site: {site_index}. Done with individual {i1}/{len(genotypes)}')
        if i1_val == -1:
            continue
        for i2 in range(i1+1, num_individuals):
            i2_val = genotypes[i2]
            if i2_val == -1:
                continue
            else:            
                # this is a valid entry, we add 1 to the count
                slice_pairwise_counts[i1][i2-i1-1] += 1
                slice_pairwise_dist[i1][i2-i1-1] += _calc_dist(i1_val, i2_val, ref_freq, non_ref_freq)

def _site_calc_pairwise_distances_with_guardrails(slice_index, num_of_slices, site_index, slice_df, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected, slice_pairwise_counts, slice_pairwise_dist):
    genotypes = slice_df.iloc[:,site_index].values
    # get counts
    num_individuals = len(genotypes)
    # count the amount of not -1 in alleles
    num_valid_genotypes = len(genotypes[genotypes!=-1])
    non_ref_count = sum(genotypes[genotypes>0])
    ref_count = 2*num_valid_genotypes-non_ref_count
    non_ref_freq = float(non_ref_count)/(2*num_valid_genotypes)
    ref_freq = float(ref_count)/(2*num_valid_genotypes)
    _log(f'Site index: {site_index}, non ref allele frequency: {non_ref_freq}')
    _log(f'Site index: {site_index}, ref allele frequency: {ref_freq}')
    # guardrails 
    assert abs(ref_freq+non_ref_freq-1)<1e-04
    _check_guardrails(num_individuals, num_valid_genotypes, ref_count, non_ref_count, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected)

    # now when we have all freq and counts, we can start the pairwise comparison
    # takes 0.5 seconds for one site. This means ~4 days if we are not seperating the task (which we will)
    # 178 sites took arounc 2 minutes.
    # Note that if we split this by chromozome, the big ones may have around 1000 in a given freq range, 
    # which can take ~8 minutes. 10k will be around 83 minutes - also cool.
    _site_calc_pairwise_distances(slice_index, num_of_slices, site_index, genotypes, num_individuals, ref_freq, non_ref_freq, slice_pairwise_counts, slice_pairwise_dist)

# %%
def _test(v1_val, v2_val):
    print(v1_val, v2_val, f'(1-f_a){(v1_val*v2_val)} + (1-f_r){(2-v1_val)*(2-v2_val)}')
for v1 in range(3):
    for v2 in range(v1,3):
        _test(v1, v2)
# Out:
# 0 0 (1-f_a)0 + (1-f_r)4
# 0 1 (1-f_a)0 + (1-f_r)2
# 0 2 (1-f_a)0 + (1-f_r)0
# 1 1 (1-f_a)1 + (1-f_r)1
# 1 2 (1-f_a)2 + (1-f_r)0
# 2 2 (1-f_a)4 + (1-f_r)0

# %%
def _calc_dist(i1_val, i2_val, ref_freq, non_ref_freq):
    # from VCFtools manual:
    # "Genotypes are represented as 0, 1 and 2, where the number represent that number of non-reference alleles"
    # So - v1_val and v2_val are the amount of non-ref alleles.
    # The distance function is:
    # 1/4[(1-f_a)(Iac+Iad) + (1-f_b)(Ibc+Ibd)]
    # Now, for each combination of v1_val and v2_val, we can compute the distance.
        
    # 0,0 - v1_val=0 and v2_val=0:
    #    1/4[(1-f_ref)(1+1) + (1-f_ref)(1+1)] = 1/4[(1-f_ref)(4)] = (1-f_ref)
    
    # 0,1 - v1_val=0 and v2_val=1:
    #    1/4[(1-f_ref)(1+0) + (1-f_ref)(1+0)] = 1/4[(1-f_ref)(2)] = 1/2(1-f_ref)
    
    # 0,2 - v1_val=0 and v2_val=2:
    #    1/4[(1-f_ref)(0+0) + (1-f_ref)(0+0)] = 0
    
    # 1,1 - v1_val=1 and v2_val=2:
    #    1/4[(1-f_non_ref)(1+0) + (1-f_ref)(1+0)] = 1/4[(1-f_non_ref)+(1-f_ref)]
    
    # 1,2 - v1_val=1 and v2_val=2:
    #    1/4[(1-f_non_ref)(1+1) + (1-f_ref)(0+0)] = 1/4[(1-f_non_ref)(2)] = 1/2(1-f_non_ref)
    
    # 2,2 - v1_val=2 and v2_val=2:
    #    1/4[(1-f_non_ref)(1+1) + (1-f_non_ref)(1+1)] = 1/4[(1-f_non_ref)(4)] = (1-f_non_ref)
    
    # Also, note that it is symetric:

    # 1,0 - v1_val=1 and v2_val=0:
    #    1/4[(1-f_ref)(1+1) + (1-f_non_ref)(0+0)] = 1/4[(1-f_ref)(2)] = 1/2(1-f_ref)
    
    # 2,1 - v1_val=2 and v2_val=1:
    #    1/4[(1-f_non_ref)(1+0) + (1-f_non_ref)(0+1)] = 1/4[(1-f_non_ref)(2)] = 1/2(1-f_non_ref)

    # 2,0 - v1_val=2 and v2_val=0:
    #    1/4[(1-f_non_ref)(0+0) + (1-f_non_ref)(0+0)] = 0
    
    # formula to use: 
    #   (1-f_non_ref)(v1_val*v2_val) + (1-f_ref)((2-v1_val)*(2-v2_val))/4
    return (1-non_ref_freq)*(i1_val*i2_val) + (1-ref_freq)*((2-i1_val)*(2-i2_val))/4

# %%
def _check_guardrails(num_individuals, num_valid_genotypes, ref_count, non_ref_count, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected):
    _log(f'Check guardrails')
    # guardrail #1 - min_valid_sites_precentage
    percentage_valid_sites = float(num_valid_genotypes)/num_individuals
    _log(f'Precentage of valid sites: {percentage_valid_sites}')
    if percentage_valid_sites < min_valid_sites_precentage:
        _log(f'ERROR: % of valid sites is {percentage_valid_sites}, lower than allowd: {min_valid_sites_precentage}.', logging.ERROR)
    # guardrail #2 - min_minor_freq_expected and max_minor_freq_expected
    minor_count = min(ref_count, non_ref_count)
    minor_freq = float(minor_count)/(2*num_valid_genotypes)
    _log(f'Minor allele frequency: {minor_freq}')
    if minor_freq < min_minor_freq_expected:
        _log(f'ERROR: minor frequency is too low - {minor_freq}, allowd: {min_minor_freq_expected}.', logging.ERROR)
    if minor_freq > max_minor_freq_expected:
        _log(f'ERROR: minor frequency is too high - {minor_freq}, allowd: {max_minor_freq_expected}.', logging.ERROR)
    _log(f'Passed guardrails')

# %%
def _write_pairwise_distances(output_dist_file, slice_pairwise_counts, slice_pairwise_dist, num_of_sites):
    #TODO
    print('todo')
    
def _write_output_sites_file(output_sites_file, slice_df):
    # TODO - output per site the calculated number of missing values and MAF
    sites_ids = slice_df.columns.values
    with open(output_sites_file, 'w') as f:
        for site_id in sites_ids:
            f.write(site_id.replace('_','\t') + '\n')

# %% [markdown]
# # Func begin

# %%
def TODO_NAME(path_to_012_files, base_output_path, desired_num_of_sites_per_output, min_minor_freq_expected, max_minor_freq_expected):
    # outputs:
    # for each group i in 1,...,k:
    # 1. {i}_dist_{l}_sites : tab seperated pairwise distances - this is the sum over the valid sites used, and the format in each entry is <sum>,<l'>, or <sum> if l'=l (from the file's name)
    # the idea here is that in most cases all entries are valid for both individuals, and there is no need to store this value. In the cases there are l'>l valid sites, we add l' to the output in the entry.
    # dummy example for 3 individuals, over l=5, where individual number 3 has 2 invalid entries (-1 -1 1 0 2)
    # 0.9 0.7,3
    # 0.8,3 
    # the ',3' indicates that there are only 3 valied sited for individuals 1 and 3 and 2 and 3
    # 2. {i}_sites_ids : <site_id> <number of non -1 entris>


    # Validate inputs
    path_012 = f'{path_to_012_files}{SUFFIX_012}'
    path_pos = f'{path_to_012_files}{SUFFIX_POS}'
    chr_name = _get_chr_name(path_pos)

    _set_logger(chr_name, min_minor_freq_expected)

    _validate_file_exist(path_012)
    _validate_file_exist(path_pos)

    # prepare output folder
    _log(f'chr_name is {chr_name}')
    output_dir = _prepare_output_folder(base_output_path, chr_name)

    # load the data
    # get sites positions to use as column names
    with open(path_pos, 'r') as f:
        sites_pos = [l.replace('\t','_').replace('\n','') for l in f.readlines()]
    all_df = pd.read_csv(path_012, sep='\t', names = ['ind_id'] + sites_pos)
    # drop first column - individual ids
    all_df = all_df.drop(columns=['ind_id'])
    num_sites = len(all_df.columns)
    num_of_slices = int(float(num_sites)/desired_num_of_sites_per_output)
    size_of_last_slice = num_sites % desired_num_of_sites_per_output
    _log(f'Total num of sites: {num_sites}')
    _log(f'Desired size of slice: {desired_num_of_sites_per_output}')
    _log(f'Number of slices: {num_of_slices+1}')
    _log(f'Size of last slice: {size_of_last_slice}')

    for slice_index in  range(num_of_slices+1):
        _log(f'{chr_name}: slice {slice_index}/{num_of_slices}')

        min_col_index = slice_index*desired_num_of_sites_per_output
        # in case we have less than desired_num_of_sites_per_output, pandas will only take those we have!
        max_col_index = min_col_index + desired_num_of_sites_per_output
        slice_df = all_df.iloc[:,min_col_index:max_col_index]
        num_of_sites = len(slice_df.columns)
        _log(f'\n#############\n')
        _log(f'Slice index: {slice_index}. Slice size: {num_of_sites} ')
        output_dist_file = output_dir + OUTPUT_PATTERN_DIST_FILE.format(slice_index=slice_index, num_of_sites=num_of_sites)
        output_sites_file = output_dir + OUTPUT_PATTERN_SITES_FILE.format(slice_index=slice_index)
        # todo - maybe write to this file also the number of -1, 0, 1 and 2?
        _write_output_sites_file(output_sites_file, slice_df)
        _log(f'Output files: {output_dist_file} {output_sites_file}')
        slice_pairwise_counts, slice_pairwise_dist = _slice_calc_pairwise_distances_with_guardrails(slice_index, num_of_slices, slice_df, min_valid_sites_precentage, min_minor_freq_expected, max_minor_freq_expected)
        _write_pairwise_distances(output_dist_file, slice_pairwise_counts, slice_pairwise_dist, num_of_sites)

# %%
TODO_NAME(path_to_012_files, base_output_path, desired_num_of_sites_per_output=100, min_minor_freq_expected=0.49, max_minor_freq_expected=0.5)
# Out:
# chr_name is chr9
# output_dir is C:\Data\HUJI\hgdp\mock/chr9/
# Total num of sites: 178
# Desired size of slice: 100
# Number of slices: 2
# Size of last slice: 78
# chr9: slice 0/1
#
# #############
#
# Slice index: 0. Slice size: 100
# Output files: C:\Data\HUJI\hgdp\mock/chr9/dist_slice_0_100_sites.tsv C:\Data\HUJI\hgdp\mock/chr9/sites_ids_slice_0.tsv
# Site index: 0, non ref allele frequency: 0.5
# Site index: 0, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.4951560818083961
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 0. Done with individual 0/929
# Slice: 0/1. Site: 0. Done with individual 100/929
# Slice: 0/1. Site: 0. Done with individual 200/929
# Slice: 0/1. Site: 0. Done with individual 300/929
# Slice: 0/1. Site: 0. Done with individual 400/929
# Slice: 0/1. Site: 0. Done with individual 500/929
# Slice: 0/1. Site: 0. Done with individual 600/929
# Slice: 0/1. Site: 0. Done with individual 700/929
# Slice: 0/1. Site: 0. Done with individual 800/929
# Slice: 0/1. Site: 0. Done with individual 900/929
# Site index: 1, non ref allele frequency: 0.5
# Site index: 1, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.4908503767491927
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 1. Done with individual 0/929
# Slice: 0/1. Site: 1. Done with individual 100/929
# Slice: 0/1. Site: 1. Done with individual 200/929
# Slice: 0/1. Site: 1. Done with individual 300/929
# Slice: 0/1. Site: 1. Done with individual 400/929
# Slice: 0/1. Site: 1. Done with individual 500/929
# Slice: 0/1. Site: 1. Done with individual 600/929
# Slice: 0/1. Site: 1. Done with individual 700/929
# Slice: 0/1. Site: 1. Done with individual 800/929
# Slice: 0/1. Site: 1. Done with individual 900/929
# Site index: 2, non ref allele frequency: 0.49746192893401014
# Site index: 2, ref allele frequency: 0.5025380710659898
# Check guardrails
# Precentage of valid sites: 0.4241119483315393
# Minor allele frequency: 0.49746192893401014
# Passed guardrails
# Slice: 0/1. Site: 2. Done with individual 0/929
# Slice: 0/1. Site: 2. Done with individual 100/929
# Slice: 0/1. Site: 2. Done with individual 200/929
# Slice: 0/1. Site: 2. Done with individual 300/929
# Slice: 0/1. Site: 2. Done with individual 400/929
# Slice: 0/1. Site: 2. Done with individual 500/929
# Slice: 0/1. Site: 2. Done with individual 600/929
# Slice: 0/1. Site: 2. Done with individual 700/929
# Slice: 0/1. Site: 2. Done with individual 800/929
# Slice: 0/1. Site: 2. Done with individual 900/929
# Site index: 3, non ref allele frequency: 0.5
# Site index: 3, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.30893433799784714
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 3. Done with individual 0/929
# Slice: 0/1. Site: 3. Done with individual 100/929
# Slice: 0/1. Site: 3. Done with individual 200/929
# Slice: 0/1. Site: 3. Done with individual 300/929
# Slice: 0/1. Site: 3. Done with individual 400/929
# Slice: 0/1. Site: 3. Done with individual 500/929
# Slice: 0/1. Site: 3. Done with individual 600/929
# Slice: 0/1. Site: 3. Done with individual 700/929
# Slice: 0/1. Site: 3. Done with individual 800/929
# Slice: 0/1. Site: 3. Done with individual 900/929
# Site index: 4, non ref allele frequency: 0.4969040247678019
# Site index: 4, ref allele frequency: 0.5030959752321982
# Check guardrails
# Precentage of valid sites: 0.34768568353067814
# Minor allele frequency: 0.4969040247678019
# Passed guardrails
# Slice: 0/1. Site: 4. Done with individual 0/929
# Slice: 0/1. Site: 4. Done with individual 100/929
# Slice: 0/1. Site: 4. Done with individual 200/929
# Slice: 0/1. Site: 4. Done with individual 300/929
# Slice: 0/1. Site: 4. Done with individual 400/929
# Slice: 0/1. Site: 4. Done with individual 500/929
# Slice: 0/1. Site: 4. Done with individual 600/929
# Slice: 0/1. Site: 4. Done with individual 700/929
# Slice: 0/1. Site: 4. Done with individual 800/929
# Slice: 0/1. Site: 4. Done with individual 900/929
# Site index: 5, non ref allele frequency: 0.49534883720930234
# Site index: 5, ref allele frequency: 0.5046511627906977
# Check guardrails
# Precentage of valid sites: 0.23143164693218515
# Minor allele frequency: 0.49534883720930234
# Passed guardrails
# Slice: 0/1. Site: 5. Done with individual 0/929
# Slice: 0/1. Site: 5. Done with individual 100/929
# Slice: 0/1. Site: 5. Done with individual 200/929
# Slice: 0/1. Site: 5. Done with individual 300/929
# Slice: 0/1. Site: 5. Done with individual 400/929
# Slice: 0/1. Site: 5. Done with individual 500/929
# Slice: 0/1. Site: 5. Done with individual 600/929
# Slice: 0/1. Site: 5. Done with individual 700/929
# Slice: 0/1. Site: 5. Done with individual 800/929
# Slice: 0/1. Site: 5. Done with individual 900/929
# Site index: 6, non ref allele frequency: 0.4935897435897436
# Site index: 6, ref allele frequency: 0.5064102564102564
# Check guardrails
# Precentage of valid sites: 0.16792249730893433
# Minor allele frequency: 0.4935897435897436
# Passed guardrails
# Slice: 0/1. Site: 6. Done with individual 0/929
# Slice: 0/1. Site: 6. Done with individual 100/929
# Slice: 0/1. Site: 6. Done with individual 200/929
# Slice: 0/1. Site: 6. Done with individual 300/929
# Slice: 0/1. Site: 6. Done with individual 400/929
# Slice: 0/1. Site: 6. Done with individual 500/929
# Slice: 0/1. Site: 6. Done with individual 600/929
# Slice: 0/1. Site: 6. Done with individual 700/929
# Slice: 0/1. Site: 6. Done with individual 800/929
# Slice: 0/1. Site: 6. Done with individual 900/929
# Site index: 7, non ref allele frequency: 0.4966442953020134
# Site index: 7, ref allele frequency: 0.5033557046979866
# Check guardrails
# Precentage of valid sites: 0.48116254036598494
# Minor allele frequency: 0.4966442953020134
# Passed guardrails
# Slice: 0/1. Site: 7. Done with individual 0/929
# Slice: 0/1. Site: 7. Done with individual 100/929
# Slice: 0/1. Site: 7. Done with individual 200/929
# Slice: 0/1. Site: 7. Done with individual 300/929
# Slice: 0/1. Site: 7. Done with individual 400/929
# Slice: 0/1. Site: 7. Done with individual 500/929
# Slice: 0/1. Site: 7. Done with individual 600/929
# Slice: 0/1. Site: 7. Done with individual 700/929
# Slice: 0/1. Site: 7. Done with individual 800/929
# Slice: 0/1. Site: 7. Done with individual 900/929
# Site index: 8, non ref allele frequency: 0.49230769230769234
# Site index: 8, ref allele frequency: 0.5076923076923077
# Check guardrails
# Precentage of valid sites: 0.34983853606027987
# Minor allele frequency: 0.49230769230769234
# Passed guardrails
# Slice: 0/1. Site: 8. Done with individual 0/929
# Slice: 0/1. Site: 8. Done with individual 100/929
# Slice: 0/1. Site: 8. Done with individual 200/929
# Slice: 0/1. Site: 8. Done with individual 300/929
# Slice: 0/1. Site: 8. Done with individual 400/929
# Slice: 0/1. Site: 8. Done with individual 500/929
# Slice: 0/1. Site: 8. Done with individual 600/929
# Slice: 0/1. Site: 8. Done with individual 700/929
# Slice: 0/1. Site: 8. Done with individual 800/929
# Slice: 0/1. Site: 8. Done with individual 900/929
# Site index: 9, non ref allele frequency: 0.494475138121547
# Site index: 9, ref allele frequency: 0.505524861878453
# Check guardrails
# Precentage of valid sites: 0.19483315392895587
# Minor allele frequency: 0.494475138121547
# Passed guardrails
# Slice: 0/1. Site: 9. Done with individual 0/929
# Slice: 0/1. Site: 9. Done with individual 100/929
# Slice: 0/1. Site: 9. Done with individual 200/929
# Slice: 0/1. Site: 9. Done with individual 300/929
# Slice: 0/1. Site: 9. Done with individual 400/929
# Slice: 0/1. Site: 9. Done with individual 500/929
# Slice: 0/1. Site: 9. Done with individual 600/929
# Slice: 0/1. Site: 9. Done with individual 700/929
# Slice: 0/1. Site: 9. Done with individual 800/929
# Slice: 0/1. Site: 9. Done with individual 900/929
# Site index: 10, non ref allele frequency: 0.4948630136986301
# Site index: 10, ref allele frequency: 0.5051369863013698
# Check guardrails
# Precentage of valid sites: 0.628632938643703
# Minor allele frequency: 0.4948630136986301
# Passed guardrails
# Slice: 0/1. Site: 10. Done with individual 0/929
# Slice: 0/1. Site: 10. Done with individual 100/929
# Slice: 0/1. Site: 10. Done with individual 200/929
# Slice: 0/1. Site: 10. Done with individual 300/929
# Slice: 0/1. Site: 10. Done with individual 400/929
# Slice: 0/1. Site: 10. Done with individual 500/929
# Slice: 0/1. Site: 10. Done with individual 600/929
# Slice: 0/1. Site: 10. Done with individual 700/929
# Slice: 0/1. Site: 10. Done with individual 800/929
# Slice: 0/1. Site: 10. Done with individual 900/929
# Site index: 11, non ref allele frequency: 0.4942434210526316
# Site index: 11, ref allele frequency: 0.5057565789473685
# Check guardrails
# Precentage of valid sites: 0.6544671689989235
# Minor allele frequency: 0.4942434210526316
# Passed guardrails
# Slice: 0/1. Site: 11. Done with individual 0/929
# Slice: 0/1. Site: 11. Done with individual 100/929
# Slice: 0/1. Site: 11. Done with individual 200/929
# Slice: 0/1. Site: 11. Done with individual 300/929
# Slice: 0/1. Site: 11. Done with individual 400/929
# Slice: 0/1. Site: 11. Done with individual 500/929
# Slice: 0/1. Site: 11. Done with individual 600/929
# Slice: 0/1. Site: 11. Done with individual 700/929
# Slice: 0/1. Site: 11. Done with individual 800/929
# Slice: 0/1. Site: 11. Done with individual 900/929
# Site index: 12, non ref allele frequency: 0.4919786096256685
# Site index: 12, ref allele frequency: 0.5080213903743316
# Check guardrails
# Precentage of valid sites: 0.20129171151776104
# Minor allele frequency: 0.4919786096256685
# Passed guardrails
# Slice: 0/1. Site: 12. Done with individual 0/929
# Slice: 0/1. Site: 12. Done with individual 100/929
# Slice: 0/1. Site: 12. Done with individual 200/929
# Slice: 0/1. Site: 12. Done with individual 300/929
# Slice: 0/1. Site: 12. Done with individual 400/929
# Slice: 0/1. Site: 12. Done with individual 500/929
# Slice: 0/1. Site: 12. Done with individual 600/929
# Slice: 0/1. Site: 12. Done with individual 700/929
# Slice: 0/1. Site: 12. Done with individual 800/929
# Slice: 0/1. Site: 12. Done with individual 900/929
# Site index: 13, non ref allele frequency: 0.4974025974025974
# Site index: 13, ref allele frequency: 0.5025974025974026
# Check guardrails
# Precentage of valid sites: 0.8288482238966631
# Minor allele frequency: 0.4974025974025974
# Passed guardrails
# Slice: 0/1. Site: 13. Done with individual 0/929
# Slice: 0/1. Site: 13. Done with individual 100/929
# Slice: 0/1. Site: 13. Done with individual 200/929
# Slice: 0/1. Site: 13. Done with individual 300/929
# Slice: 0/1. Site: 13. Done with individual 400/929
# Slice: 0/1. Site: 13. Done with individual 500/929
# Slice: 0/1. Site: 13. Done with individual 600/929
# Slice: 0/1. Site: 13. Done with individual 700/929
# Slice: 0/1. Site: 13. Done with individual 800/929
# Slice: 0/1. Site: 13. Done with individual 900/929
# Site index: 14, non ref allele frequency: 0.5
# Site index: 14, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.48869752421959095
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 14. Done with individual 0/929
# Slice: 0/1. Site: 14. Done with individual 100/929
# Slice: 0/1. Site: 14. Done with individual 200/929
# Slice: 0/1. Site: 14. Done with individual 300/929
# Slice: 0/1. Site: 14. Done with individual 400/929
# Slice: 0/1. Site: 14. Done with individual 500/929
# Slice: 0/1. Site: 14. Done with individual 600/929
# Slice: 0/1. Site: 14. Done with individual 700/929
# Slice: 0/1. Site: 14. Done with individual 800/929
# Slice: 0/1. Site: 14. Done with individual 900/929
# Site index: 15, non ref allele frequency: 0.5
# Site index: 15, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.6275565123789021
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 15. Done with individual 0/929
# Slice: 0/1. Site: 15. Done with individual 100/929
# Slice: 0/1. Site: 15. Done with individual 200/929
# Slice: 0/1. Site: 15. Done with individual 300/929
# Slice: 0/1. Site: 15. Done with individual 400/929
# Slice: 0/1. Site: 15. Done with individual 500/929
# Slice: 0/1. Site: 15. Done with individual 600/929
# Slice: 0/1. Site: 15. Done with individual 700/929
# Slice: 0/1. Site: 15. Done with individual 800/929
# Slice: 0/1. Site: 15. Done with individual 900/929
# Site index: 16, non ref allele frequency: 0.5
# Site index: 16, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.5608180839612487
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 16. Done with individual 0/929
# Slice: 0/1. Site: 16. Done with individual 100/929
# Slice: 0/1. Site: 16. Done with individual 200/929
# Slice: 0/1. Site: 16. Done with individual 300/929
# Slice: 0/1. Site: 16. Done with individual 400/929
# Slice: 0/1. Site: 16. Done with individual 500/929
# Slice: 0/1. Site: 16. Done with individual 600/929
# Slice: 0/1. Site: 16. Done with individual 700/929
# Slice: 0/1. Site: 16. Done with individual 800/929
# Slice: 0/1. Site: 16. Done with individual 900/929
# Site index: 17, non ref allele frequency: 0.49280575539568344
# Site index: 17, ref allele frequency: 0.5071942446043165
# Check guardrails
# Precentage of valid sites: 0.1496232508073197
# Minor allele frequency: 0.49280575539568344
# Passed guardrails
# Slice: 0/1. Site: 17. Done with individual 0/929
# Slice: 0/1. Site: 17. Done with individual 100/929
# Slice: 0/1. Site: 17. Done with individual 200/929
# Slice: 0/1. Site: 17. Done with individual 300/929
# Slice: 0/1. Site: 17. Done with individual 400/929
# Slice: 0/1. Site: 17. Done with individual 500/929
# Slice: 0/1. Site: 17. Done with individual 600/929
# Slice: 0/1. Site: 17. Done with individual 700/929
# Slice: 0/1. Site: 17. Done with individual 800/929
# Slice: 0/1. Site: 17. Done with individual 900/929
# Site index: 18, non ref allele frequency: 0.5
# Site index: 18, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.5059203444564048
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 18. Done with individual 0/929
# Slice: 0/1. Site: 18. Done with individual 100/929
# Slice: 0/1. Site: 18. Done with individual 200/929
# Slice: 0/1. Site: 18. Done with individual 300/929
# Slice: 0/1. Site: 18. Done with individual 400/929
# Slice: 0/1. Site: 18. Done with individual 500/929
# Slice: 0/1. Site: 18. Done with individual 600/929
# Slice: 0/1. Site: 18. Done with individual 700/929
# Slice: 0/1. Site: 18. Done with individual 800/929
# Slice: 0/1. Site: 18. Done with individual 900/929
# Site index: 19, non ref allele frequency: 0.5
# Site index: 19, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.37782561894510225
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 19. Done with individual 0/929
# Slice: 0/1. Site: 19. Done with individual 100/929
# Slice: 0/1. Site: 19. Done with individual 200/929
# Slice: 0/1. Site: 19. Done with individual 300/929
# Slice: 0/1. Site: 19. Done with individual 400/929
# Slice: 0/1. Site: 19. Done with individual 500/929
# Slice: 0/1. Site: 19. Done with individual 600/929
# Slice: 0/1. Site: 19. Done with individual 700/929
# Slice: 0/1. Site: 19. Done with individual 800/929
# Slice: 0/1. Site: 19. Done with individual 900/929
# Site index: 20, non ref allele frequency: 0.5
# Site index: 20, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.47255113024757806
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 20. Done with individual 0/929
# Slice: 0/1. Site: 20. Done with individual 100/929
# Slice: 0/1. Site: 20. Done with individual 200/929
# Slice: 0/1. Site: 20. Done with individual 300/929
# Slice: 0/1. Site: 20. Done with individual 400/929
# Slice: 0/1. Site: 20. Done with individual 500/929
# Slice: 0/1. Site: 20. Done with individual 600/929
# Slice: 0/1. Site: 20. Done with individual 700/929
# Slice: 0/1. Site: 20. Done with individual 800/929
# Slice: 0/1. Site: 20. Done with individual 900/929
# Site index: 21, non ref allele frequency: 0.5
# Site index: 21, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.7265877287405813
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 21. Done with individual 0/929
# Slice: 0/1. Site: 21. Done with individual 100/929
# Slice: 0/1. Site: 21. Done with individual 200/929
# Slice: 0/1. Site: 21. Done with individual 300/929
# Slice: 0/1. Site: 21. Done with individual 400/929
# Slice: 0/1. Site: 21. Done with individual 500/929
# Slice: 0/1. Site: 21. Done with individual 600/929
# Slice: 0/1. Site: 21. Done with individual 700/929
# Slice: 0/1. Site: 21. Done with individual 800/929
# Slice: 0/1. Site: 21. Done with individual 900/929
# Site index: 22, non ref allele frequency: 0.5
# Site index: 22, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.25834230355220666
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 22. Done with individual 0/929
# Slice: 0/1. Site: 22. Done with individual 100/929
# Slice: 0/1. Site: 22. Done with individual 200/929
# Slice: 0/1. Site: 22. Done with individual 300/929
# Slice: 0/1. Site: 22. Done with individual 400/929
# Slice: 0/1. Site: 22. Done with individual 500/929
# Slice: 0/1. Site: 22. Done with individual 600/929
# Slice: 0/1. Site: 22. Done with individual 700/929
# Slice: 0/1. Site: 22. Done with individual 800/929
# Slice: 0/1. Site: 22. Done with individual 900/929
# Site index: 23, non ref allele frequency: 0.49099099099099097
# Site index: 23, ref allele frequency: 0.509009009009009
# Check guardrails
# Precentage of valid sites: 0.11948331539289558
# Minor allele frequency: 0.49099099099099097
# Passed guardrails
# Slice: 0/1. Site: 23. Done with individual 0/929
# Slice: 0/1. Site: 23. Done with individual 100/929
# Slice: 0/1. Site: 23. Done with individual 200/929
# Slice: 0/1. Site: 23. Done with individual 300/929
# Slice: 0/1. Site: 23. Done with individual 400/929
# Slice: 0/1. Site: 23. Done with individual 500/929
# Slice: 0/1. Site: 23. Done with individual 600/929
# Slice: 0/1. Site: 23. Done with individual 700/929
# Slice: 0/1. Site: 23. Done with individual 800/929
# Slice: 0/1. Site: 23. Done with individual 900/929
# Site index: 24, non ref allele frequency: 0.4976190476190476
# Site index: 24, ref allele frequency: 0.5023809523809524
# Check guardrails
# Precentage of valid sites: 0.22604951560818085
# Minor allele frequency: 0.4976190476190476
# Passed guardrails
# Slice: 0/1. Site: 24. Done with individual 0/929
# Slice: 0/1. Site: 24. Done with individual 100/929
# Slice: 0/1. Site: 24. Done with individual 200/929
# Slice: 0/1. Site: 24. Done with individual 300/929
# Slice: 0/1. Site: 24. Done with individual 400/929
# Slice: 0/1. Site: 24. Done with individual 500/929
# Slice: 0/1. Site: 24. Done with individual 600/929
# Slice: 0/1. Site: 24. Done with individual 700/929
# Slice: 0/1. Site: 24. Done with individual 800/929
# Slice: 0/1. Site: 24. Done with individual 900/929
# Site index: 25, non ref allele frequency: 0.5
# Site index: 25, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.8460710441334769
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 25. Done with individual 0/929
# Slice: 0/1. Site: 25. Done with individual 100/929
# Slice: 0/1. Site: 25. Done with individual 200/929
# Slice: 0/1. Site: 25. Done with individual 300/929
# Slice: 0/1. Site: 25. Done with individual 400/929
# Slice: 0/1. Site: 25. Done with individual 500/929
# Slice: 0/1. Site: 25. Done with individual 600/929
# Slice: 0/1. Site: 25. Done with individual 700/929
# Slice: 0/1. Site: 25. Done with individual 800/929
# Slice: 0/1. Site: 25. Done with individual 900/929
# Site index: 26, non ref allele frequency: 0.5
# Site index: 26, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.8385360602798708
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 26. Done with individual 0/929
# Slice: 0/1. Site: 26. Done with individual 100/929
# Slice: 0/1. Site: 26. Done with individual 200/929
# Slice: 0/1. Site: 26. Done with individual 300/929
# Slice: 0/1. Site: 26. Done with individual 400/929
# Slice: 0/1. Site: 26. Done with individual 500/929
# Slice: 0/1. Site: 26. Done with individual 600/929
# Slice: 0/1. Site: 26. Done with individual 700/929
# Slice: 0/1. Site: 26. Done with individual 800/929
# Slice: 0/1. Site: 26. Done with individual 900/929
# Site index: 27, non ref allele frequency: 0.49473684210526314
# Site index: 27, ref allele frequency: 0.5052631578947369
# Check guardrails
# Precentage of valid sites: 0.40904198062432723
# Minor allele frequency: 0.49473684210526314
# Passed guardrails
# Slice: 0/1. Site: 27. Done with individual 0/929
# Slice: 0/1. Site: 27. Done with individual 100/929
# Slice: 0/1. Site: 27. Done with individual 200/929
# Slice: 0/1. Site: 27. Done with individual 300/929
# Slice: 0/1. Site: 27. Done with individual 400/929
# Slice: 0/1. Site: 27. Done with individual 500/929
# Slice: 0/1. Site: 27. Done with individual 600/929
# Slice: 0/1. Site: 27. Done with individual 700/929
# Slice: 0/1. Site: 27. Done with individual 800/929
# Slice: 0/1. Site: 27. Done with individual 900/929
# Site index: 28, non ref allele frequency: 0.5
# Site index: 28, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.5317545748116254
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 28. Done with individual 0/929
# Slice: 0/1. Site: 28. Done with individual 100/929
# Slice: 0/1. Site: 28. Done with individual 200/929
# Slice: 0/1. Site: 28. Done with individual 300/929
# Slice: 0/1. Site: 28. Done with individual 400/929
# Slice: 0/1. Site: 28. Done with individual 500/929
# Slice: 0/1. Site: 28. Done with individual 600/929
# Slice: 0/1. Site: 28. Done with individual 700/929
# Slice: 0/1. Site: 28. Done with individual 800/929
# Slice: 0/1. Site: 28. Done with individual 900/929
# Site index: 29, non ref allele frequency: 0.5
# Site index: 29, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.24865446716899892
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 29. Done with individual 0/929
# Slice: 0/1. Site: 29. Done with individual 100/929
# Slice: 0/1. Site: 29. Done with individual 200/929
# Slice: 0/1. Site: 29. Done with individual 300/929
# Slice: 0/1. Site: 29. Done with individual 400/929
# Slice: 0/1. Site: 29. Done with individual 500/929
# Slice: 0/1. Site: 29. Done with individual 600/929
# Slice: 0/1. Site: 29. Done with individual 700/929
# Slice: 0/1. Site: 29. Done with individual 800/929
# Slice: 0/1. Site: 29. Done with individual 900/929
# Site index: 30, non ref allele frequency: 0.5
# Site index: 30, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.11410118406889128
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 30. Done with individual 0/929
# Slice: 0/1. Site: 30. Done with individual 100/929
# Slice: 0/1. Site: 30. Done with individual 200/929
# Slice: 0/1. Site: 30. Done with individual 300/929
# Slice: 0/1. Site: 30. Done with individual 400/929
# Slice: 0/1. Site: 30. Done with individual 500/929
# Slice: 0/1. Site: 30. Done with individual 600/929
# Slice: 0/1. Site: 30. Done with individual 700/929
# Slice: 0/1. Site: 30. Done with individual 800/929
# Slice: 0/1. Site: 30. Done with individual 900/929
# Site index: 31, non ref allele frequency: 0.49330357142857145
# Site index: 31, ref allele frequency: 0.5066964285714286
# Check guardrails
# Precentage of valid sites: 0.4822389666307858
# Minor allele frequency: 0.49330357142857145
# Passed guardrails
# Slice: 0/1. Site: 31. Done with individual 0/929
# Slice: 0/1. Site: 31. Done with individual 100/929
# Slice: 0/1. Site: 31. Done with individual 200/929
# Slice: 0/1. Site: 31. Done with individual 300/929
# Slice: 0/1. Site: 31. Done with individual 400/929
# Slice: 0/1. Site: 31. Done with individual 500/929
# Slice: 0/1. Site: 31. Done with individual 600/929
# Slice: 0/1. Site: 31. Done with individual 700/929
# Slice: 0/1. Site: 31. Done with individual 800/929
# Slice: 0/1. Site: 31. Done with individual 900/929
# Site index: 32, non ref allele frequency: 0.4931506849315068
# Site index: 32, ref allele frequency: 0.5068493150684932
# Check guardrails
# Precentage of valid sites: 0.55005382131324
# Minor allele frequency: 0.4931506849315068
# Passed guardrails
# Slice: 0/1. Site: 32. Done with individual 0/929
# Slice: 0/1. Site: 32. Done with individual 100/929
# Slice: 0/1. Site: 32. Done with individual 200/929
# Slice: 0/1. Site: 32. Done with individual 300/929
# Slice: 0/1. Site: 32. Done with individual 400/929
# Slice: 0/1. Site: 32. Done with individual 500/929
# Slice: 0/1. Site: 32. Done with individual 600/929
# Slice: 0/1. Site: 32. Done with individual 700/929
# Slice: 0/1. Site: 32. Done with individual 800/929
# Slice: 0/1. Site: 32. Done with individual 900/929
# Site index: 33, non ref allele frequency: 0.49580712788259956
# Site index: 33, ref allele frequency: 0.5041928721174004
# Check guardrails
# Precentage of valid sites: 0.5134553283100107
# Minor allele frequency: 0.49580712788259956
# Passed guardrails
# Slice: 0/1. Site: 33. Done with individual 0/929
# Slice: 0/1. Site: 33. Done with individual 100/929
# Slice: 0/1. Site: 33. Done with individual 200/929
# Slice: 0/1. Site: 33. Done with individual 300/929
# Slice: 0/1. Site: 33. Done with individual 400/929
# Slice: 0/1. Site: 33. Done with individual 500/929
# Slice: 0/1. Site: 33. Done with individual 600/929
# Slice: 0/1. Site: 33. Done with individual 700/929
# Slice: 0/1. Site: 33. Done with individual 800/929
# Slice: 0/1. Site: 33. Done with individual 900/929
# Site index: 34, non ref allele frequency: 0.506578947368421
# Site index: 34, ref allele frequency: 0.4934210526315789
# Check guardrails
# Precentage of valid sites: 0.40904198062432723
# Minor allele frequency: 0.4934210526315789
# Passed guardrails
# Slice: 0/1. Site: 34. Done with individual 0/929
# Slice: 0/1. Site: 34. Done with individual 100/929
# Slice: 0/1. Site: 34. Done with individual 200/929
# Slice: 0/1. Site: 34. Done with individual 300/929
# Slice: 0/1. Site: 34. Done with individual 400/929
# Slice: 0/1. Site: 34. Done with individual 500/929
# Slice: 0/1. Site: 34. Done with individual 600/929
# Slice: 0/1. Site: 34. Done with individual 700/929
# Slice: 0/1. Site: 34. Done with individual 800/929
# Slice: 0/1. Site: 34. Done with individual 900/929
# Site index: 35, non ref allele frequency: 0.49012158054711247
# Site index: 35, ref allele frequency: 0.5098784194528876
# Check guardrails
# Precentage of valid sites: 0.7082884822389667
# Minor allele frequency: 0.49012158054711247
# Passed guardrails
# Slice: 0/1. Site: 35. Done with individual 0/929
# Slice: 0/1. Site: 35. Done with individual 100/929
# Slice: 0/1. Site: 35. Done with individual 200/929
# Slice: 0/1. Site: 35. Done with individual 300/929
# Slice: 0/1. Site: 35. Done with individual 400/929
# Slice: 0/1. Site: 35. Done with individual 500/929
# Slice: 0/1. Site: 35. Done with individual 600/929
# Slice: 0/1. Site: 35. Done with individual 700/929
# Slice: 0/1. Site: 35. Done with individual 800/929
# Slice: 0/1. Site: 35. Done with individual 900/929
# Site index: 36, non ref allele frequency: 0.5015948963317385
# Site index: 36, ref allele frequency: 0.4984051036682616
# Check guardrails
# Precentage of valid sites: 0.6749192680301399
# Minor allele frequency: 0.4984051036682616
# Passed guardrails
# Slice: 0/1. Site: 36. Done with individual 0/929
# Slice: 0/1. Site: 36. Done with individual 100/929
# Slice: 0/1. Site: 36. Done with individual 200/929
# Slice: 0/1. Site: 36. Done with individual 300/929
# Slice: 0/1. Site: 36. Done with individual 400/929
# Slice: 0/1. Site: 36. Done with individual 500/929
# Slice: 0/1. Site: 36. Done with individual 600/929
# Slice: 0/1. Site: 36. Done with individual 700/929
# Slice: 0/1. Site: 36. Done with individual 800/929
# Slice: 0/1. Site: 36. Done with individual 900/929
# Site index: 37, non ref allele frequency: 0.5
# Site index: 37, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.7319698600645855
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 37. Done with individual 0/929
# Slice: 0/1. Site: 37. Done with individual 100/929
# Slice: 0/1. Site: 37. Done with individual 200/929
# Slice: 0/1. Site: 37. Done with individual 300/929
# Slice: 0/1. Site: 37. Done with individual 400/929
# Slice: 0/1. Site: 37. Done with individual 500/929
# Slice: 0/1. Site: 37. Done with individual 600/929
# Slice: 0/1. Site: 37. Done with individual 700/929
# Slice: 0/1. Site: 37. Done with individual 800/929
# Slice: 0/1. Site: 37. Done with individual 900/929
# Site index: 38, non ref allele frequency: 0.5
# Site index: 38, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.3627556512378902
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 38. Done with individual 0/929
# Slice: 0/1. Site: 38. Done with individual 100/929
# Slice: 0/1. Site: 38. Done with individual 200/929
# Slice: 0/1. Site: 38. Done with individual 300/929
# Slice: 0/1. Site: 38. Done with individual 400/929
# Slice: 0/1. Site: 38. Done with individual 500/929
# Slice: 0/1. Site: 38. Done with individual 600/929
# Slice: 0/1. Site: 38. Done with individual 700/929
# Slice: 0/1. Site: 38. Done with individual 800/929
# Slice: 0/1. Site: 38. Done with individual 900/929
# Site index: 39, non ref allele frequency: 0.4951923076923077
# Site index: 39, ref allele frequency: 0.5048076923076923
# Check guardrails
# Precentage of valid sites: 0.2238966630785791
# Minor allele frequency: 0.4951923076923077
# Passed guardrails
# Slice: 0/1. Site: 39. Done with individual 0/929
# Slice: 0/1. Site: 39. Done with individual 100/929
# Slice: 0/1. Site: 39. Done with individual 200/929
# Slice: 0/1. Site: 39. Done with individual 300/929
# Slice: 0/1. Site: 39. Done with individual 400/929
# Slice: 0/1. Site: 39. Done with individual 500/929
# Slice: 0/1. Site: 39. Done with individual 600/929
# Slice: 0/1. Site: 39. Done with individual 700/929
# Slice: 0/1. Site: 39. Done with individual 800/929
# Slice: 0/1. Site: 39. Done with individual 900/929
# Site index: 40, non ref allele frequency: 0.49707602339181284
# Site index: 40, ref allele frequency: 0.5029239766081871
# Check guardrails
# Precentage of valid sites: 0.18406889128094725
# Minor allele frequency: 0.49707602339181284
# Passed guardrails
# Slice: 0/1. Site: 40. Done with individual 0/929
# Slice: 0/1. Site: 40. Done with individual 100/929
# Slice: 0/1. Site: 40. Done with individual 200/929
# Slice: 0/1. Site: 40. Done with individual 300/929
# Slice: 0/1. Site: 40. Done with individual 400/929
# Slice: 0/1. Site: 40. Done with individual 500/929
# Slice: 0/1. Site: 40. Done with individual 600/929
# Slice: 0/1. Site: 40. Done with individual 700/929
# Slice: 0/1. Site: 40. Done with individual 800/929
# Slice: 0/1. Site: 40. Done with individual 900/929
# Site index: 41, non ref allele frequency: 0.4909090909090909
# Site index: 41, ref allele frequency: 0.509090909090909
# Check guardrails
# Precentage of valid sites: 0.7104413347685683
# Minor allele frequency: 0.4909090909090909
# Passed guardrails
# Slice: 0/1. Site: 41. Done with individual 0/929
# Slice: 0/1. Site: 41. Done with individual 100/929
# Slice: 0/1. Site: 41. Done with individual 200/929
# Slice: 0/1. Site: 41. Done with individual 300/929
# Slice: 0/1. Site: 41. Done with individual 400/929
# Slice: 0/1. Site: 41. Done with individual 500/929
# Slice: 0/1. Site: 41. Done with individual 600/929
# Slice: 0/1. Site: 41. Done with individual 700/929
# Slice: 0/1. Site: 41. Done with individual 800/929
# Slice: 0/1. Site: 41. Done with individual 900/929
# Site index: 42, non ref allele frequency: 0.4985549132947977
# Site index: 42, ref allele frequency: 0.5014450867052023
# Check guardrails
# Precentage of valid sites: 0.7448869752421959
# Minor allele frequency: 0.4985549132947977
# Passed guardrails
# Slice: 0/1. Site: 42. Done with individual 0/929
# Slice: 0/1. Site: 42. Done with individual 100/929
# Slice: 0/1. Site: 42. Done with individual 200/929
# Slice: 0/1. Site: 42. Done with individual 300/929
# Slice: 0/1. Site: 42. Done with individual 400/929
# Slice: 0/1. Site: 42. Done with individual 500/929
# Slice: 0/1. Site: 42. Done with individual 600/929
# Slice: 0/1. Site: 42. Done with individual 700/929
# Slice: 0/1. Site: 42. Done with individual 800/929
# Slice: 0/1. Site: 42. Done with individual 900/929
# Site index: 43, non ref allele frequency: 0.5094339622641509
# Site index: 43, ref allele frequency: 0.49056603773584906
# Check guardrails
# Precentage of valid sites: 0.5705059203444564
# Minor allele frequency: 0.49056603773584906
# Passed guardrails
# Slice: 0/1. Site: 43. Done with individual 0/929
# Slice: 0/1. Site: 43. Done with individual 100/929
# Slice: 0/1. Site: 43. Done with individual 200/929
# Slice: 0/1. Site: 43. Done with individual 300/929
# Slice: 0/1. Site: 43. Done with individual 400/929
# Slice: 0/1. Site: 43. Done with individual 500/929
# Slice: 0/1. Site: 43. Done with individual 600/929
# Slice: 0/1. Site: 43. Done with individual 700/929
# Slice: 0/1. Site: 43. Done with individual 800/929
# Slice: 0/1. Site: 43. Done with individual 900/929
# Site index: 44, non ref allele frequency: 0.49887133182844245
# Site index: 44, ref allele frequency: 0.5011286681715575
# Check guardrails
# Precentage of valid sites: 0.47685683530678147
# Minor allele frequency: 0.49887133182844245
# Passed guardrails
# Slice: 0/1. Site: 44. Done with individual 0/929
# Slice: 0/1. Site: 44. Done with individual 100/929
# Slice: 0/1. Site: 44. Done with individual 200/929
# Slice: 0/1. Site: 44. Done with individual 300/929
# Slice: 0/1. Site: 44. Done with individual 400/929
# Slice: 0/1. Site: 44. Done with individual 500/929
# Slice: 0/1. Site: 44. Done with individual 600/929
# Slice: 0/1. Site: 44. Done with individual 700/929
# Slice: 0/1. Site: 44. Done with individual 800/929
# Slice: 0/1. Site: 44. Done with individual 900/929
# Site index: 45, non ref allele frequency: 0.4919678714859438
# Site index: 45, ref allele frequency: 0.5080321285140562
# Check guardrails
# Precentage of valid sites: 0.2680301399354144
# Minor allele frequency: 0.4919678714859438
# Passed guardrails
# Slice: 0/1. Site: 45. Done with individual 0/929
# Slice: 0/1. Site: 45. Done with individual 100/929
# Slice: 0/1. Site: 45. Done with individual 200/929
# Slice: 0/1. Site: 45. Done with individual 300/929
# Slice: 0/1. Site: 45. Done with individual 400/929
# Slice: 0/1. Site: 45. Done with individual 500/929
# Slice: 0/1. Site: 45. Done with individual 600/929
# Slice: 0/1. Site: 45. Done with individual 700/929
# Slice: 0/1. Site: 45. Done with individual 800/929
# Slice: 0/1. Site: 45. Done with individual 900/929
# Site index: 46, non ref allele frequency: 0.4929742388758782
# Site index: 46, ref allele frequency: 0.5070257611241218
# Check guardrails
# Precentage of valid sites: 0.4596340150699677
# Minor allele frequency: 0.4929742388758782
# Passed guardrails
# Slice: 0/1. Site: 46. Done with individual 0/929
# Slice: 0/1. Site: 46. Done with individual 100/929
# Slice: 0/1. Site: 46. Done with individual 200/929
# Slice: 0/1. Site: 46. Done with individual 300/929
# Slice: 0/1. Site: 46. Done with individual 400/929
# Slice: 0/1. Site: 46. Done with individual 500/929
# Slice: 0/1. Site: 46. Done with individual 600/929
# Slice: 0/1. Site: 46. Done with individual 700/929
# Slice: 0/1. Site: 46. Done with individual 800/929
# Slice: 0/1. Site: 46. Done with individual 900/929
# Site index: 47, non ref allele frequency: 0.4991103202846975
# Site index: 47, ref allele frequency: 0.5008896797153025
# Check guardrails
# Precentage of valid sites: 0.604951560818084
# Minor allele frequency: 0.4991103202846975
# Passed guardrails
# Slice: 0/1. Site: 47. Done with individual 0/929
# Slice: 0/1. Site: 47. Done with individual 100/929
# Slice: 0/1. Site: 47. Done with individual 200/929
# Slice: 0/1. Site: 47. Done with individual 300/929
# Slice: 0/1. Site: 47. Done with individual 400/929
# Slice: 0/1. Site: 47. Done with individual 500/929
# Slice: 0/1. Site: 47. Done with individual 600/929
# Slice: 0/1. Site: 47. Done with individual 700/929
# Slice: 0/1. Site: 47. Done with individual 800/929
# Slice: 0/1. Site: 47. Done with individual 900/929
# Site index: 48, non ref allele frequency: 0.5
# Site index: 48, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.620021528525296
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 48. Done with individual 0/929
# Slice: 0/1. Site: 48. Done with individual 100/929
# Slice: 0/1. Site: 48. Done with individual 200/929
# Slice: 0/1. Site: 48. Done with individual 300/929
# Slice: 0/1. Site: 48. Done with individual 400/929
# Slice: 0/1. Site: 48. Done with individual 500/929
# Slice: 0/1. Site: 48. Done with individual 600/929
# Slice: 0/1. Site: 48. Done with individual 700/929
# Slice: 0/1. Site: 48. Done with individual 800/929
# Slice: 0/1. Site: 48. Done with individual 900/929
# Site index: 49, non ref allele frequency: 0.5
# Site index: 49, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.9364908503767492
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 49. Done with individual 0/929
# Slice: 0/1. Site: 49. Done with individual 100/929
# Slice: 0/1. Site: 49. Done with individual 200/929
# Slice: 0/1. Site: 49. Done with individual 300/929
# Slice: 0/1. Site: 49. Done with individual 400/929
# Slice: 0/1. Site: 49. Done with individual 500/929
# Slice: 0/1. Site: 49. Done with individual 600/929
# Slice: 0/1. Site: 49. Done with individual 700/929
# Slice: 0/1. Site: 49. Done with individual 800/929
# Slice: 0/1. Site: 49. Done with individual 900/929
# Site index: 50, non ref allele frequency: 0.5
# Site index: 50, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.9117330462863293
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 50. Done with individual 0/929
# Slice: 0/1. Site: 50. Done with individual 100/929
# Slice: 0/1. Site: 50. Done with individual 200/929
# Slice: 0/1. Site: 50. Done with individual 300/929
# Slice: 0/1. Site: 50. Done with individual 400/929
# Slice: 0/1. Site: 50. Done with individual 500/929
# Slice: 0/1. Site: 50. Done with individual 600/929
# Slice: 0/1. Site: 50. Done with individual 700/929
# Slice: 0/1. Site: 50. Done with individual 800/929
# Slice: 0/1. Site: 50. Done with individual 900/929
# Site index: 51, non ref allele frequency: 0.5
# Site index: 51, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.8708288482238966
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 51. Done with individual 0/929
# Slice: 0/1. Site: 51. Done with individual 100/929
# Slice: 0/1. Site: 51. Done with individual 200/929
# Slice: 0/1. Site: 51. Done with individual 300/929
# Slice: 0/1. Site: 51. Done with individual 400/929
# Slice: 0/1. Site: 51. Done with individual 500/929
# Slice: 0/1. Site: 51. Done with individual 600/929
# Slice: 0/1. Site: 51. Done with individual 700/929
# Slice: 0/1. Site: 51. Done with individual 800/929
# Slice: 0/1. Site: 51. Done with individual 900/929
# Site index: 52, non ref allele frequency: 0.5
# Site index: 52, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.8783638320775027
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 52. Done with individual 0/929
# Slice: 0/1. Site: 52. Done with individual 100/929
# Slice: 0/1. Site: 52. Done with individual 200/929
# Slice: 0/1. Site: 52. Done with individual 300/929
# Slice: 0/1. Site: 52. Done with individual 400/929
# Slice: 0/1. Site: 52. Done with individual 500/929
# Slice: 0/1. Site: 52. Done with individual 600/929
# Slice: 0/1. Site: 52. Done with individual 700/929
# Slice: 0/1. Site: 52. Done with individual 800/929
# Slice: 0/1. Site: 52. Done with individual 900/929
# Site index: 53, non ref allele frequency: 0.49823321554770317
# Site index: 53, ref allele frequency: 0.5017667844522968
# Check guardrails
# Precentage of valid sites: 0.6092572658772875
# Minor allele frequency: 0.49823321554770317
# Passed guardrails
# Slice: 0/1. Site: 53. Done with individual 0/929
# Slice: 0/1. Site: 53. Done with individual 100/929
# Slice: 0/1. Site: 53. Done with individual 200/929
# Slice: 0/1. Site: 53. Done with individual 300/929
# Slice: 0/1. Site: 53. Done with individual 400/929
# Slice: 0/1. Site: 53. Done with individual 500/929
# Slice: 0/1. Site: 53. Done with individual 600/929
# Slice: 0/1. Site: 53. Done with individual 700/929
# Slice: 0/1. Site: 53. Done with individual 800/929
# Slice: 0/1. Site: 53. Done with individual 900/929
# Site index: 54, non ref allele frequency: 0.5
# Site index: 54, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.13885898815931108
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 54. Done with individual 0/929
# Slice: 0/1. Site: 54. Done with individual 100/929
# Slice: 0/1. Site: 54. Done with individual 200/929
# Slice: 0/1. Site: 54. Done with individual 300/929
# Slice: 0/1. Site: 54. Done with individual 400/929
# Slice: 0/1. Site: 54. Done with individual 500/929
# Slice: 0/1. Site: 54. Done with individual 600/929
# Slice: 0/1. Site: 54. Done with individual 700/929
# Slice: 0/1. Site: 54. Done with individual 800/929
# Slice: 0/1. Site: 54. Done with individual 900/929
# Site index: 55, non ref allele frequency: 0.4964622641509434
# Site index: 55, ref allele frequency: 0.5035377358490566
# Check guardrails
# Precentage of valid sites: 0.4564047362755651
# Minor allele frequency: 0.4964622641509434
# Passed guardrails
# Slice: 0/1. Site: 55. Done with individual 0/929
# Slice: 0/1. Site: 55. Done with individual 100/929
# Slice: 0/1. Site: 55. Done with individual 200/929
# Slice: 0/1. Site: 55. Done with individual 300/929
# Slice: 0/1. Site: 55. Done with individual 400/929
# Slice: 0/1. Site: 55. Done with individual 500/929
# Slice: 0/1. Site: 55. Done with individual 600/929
# Slice: 0/1. Site: 55. Done with individual 700/929
# Slice: 0/1. Site: 55. Done with individual 800/929
# Slice: 0/1. Site: 55. Done with individual 900/929
# Site index: 56, non ref allele frequency: 0.5
# Site index: 56, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.6921420882669537
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 56. Done with individual 0/929
# Slice: 0/1. Site: 56. Done with individual 100/929
# Slice: 0/1. Site: 56. Done with individual 200/929
# Slice: 0/1. Site: 56. Done with individual 300/929
# Slice: 0/1. Site: 56. Done with individual 400/929
# Slice: 0/1. Site: 56. Done with individual 500/929
# Slice: 0/1. Site: 56. Done with individual 600/929
# Slice: 0/1. Site: 56. Done with individual 700/929
# Slice: 0/1. Site: 56. Done with individual 800/929
# Slice: 0/1. Site: 56. Done with individual 900/929
# Site index: 57, non ref allele frequency: 0.5
# Site index: 57, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.5640473627556513
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 0/1. Site: 57. Done with individual 0/929
# Slice: 0/1. Site: 57. Done with individual 100/929
# Slice: 0/1. Site: 57. Done with individual 200/929
# Slice: 0/1. Site: 57. Done with individual 300/929
# Slice: 0/1. Site: 57. Done with individual 400/929
# Slice: 0/1. Site: 57. Done with individual 500/929
# Slice: 0/1. Site: 57. Done with individual 600/929
# Slice: 0/1. Site: 57. Done with individual 700/929
# Slice: 0/1. Site: 57. Done with individual 800/929
# Slice: 0/1. Site: 57. Done with individual 900/929
# Site index: 58, non ref allele frequency: 0.502127659574468
# Site index: 58, ref allele frequency: 0.4978723404255319
# Check guardrails
# Precentage of valid sites: 0.5059203444564048
# Minor allele frequency: 0.4978723404255319
# Passed guardrails
# Slice: 0/1. Site: 58. Done with individual 0/929
# Slice: 0/1. Site: 58. Done with individual 100/929
# Slice: 0/1. Site: 58. Done with individual 200/929
# Slice: 0/1. Site: 58. Done with individual 300/929
# Slice: 0/1. Site: 58. Done with individual 400/929
# Slice: 0/1. Site: 58. Done with individual 500/929
# Slice: 0/1. Site: 58. Done with individual 600/929
# Slice: 0/1. Site: 58. Done with individual 700/929
# Slice: 0/1. Site: 58. Done with individual 800/929
# Slice: 0/1. Site: 58. Done with individual 900/929
# Site index: 59, non ref allele frequency: 0.49029126213592233
# Site index: 59, ref allele frequency: 0.5097087378640777
# Check guardrails
# Precentage of valid sites: 0.1108719052744887
# Minor allele frequency: 0.49029126213592233
# Passed guardrails
# Slice: 0/1. Site: 59. Done with individual 0/929
# Slice: 0/1. Site: 59. Done with individual 100/929
# Slice: 0/1. Site: 59. Done with individual 200/929
# Slice: 0/1. Site: 59. Done with individual 300/929
# Slice: 0/1. Site: 59. Done with individual 400/929
# Slice: 0/1. Site: 59. Done with individual 500/929
# Slice: 0/1. Site: 59. Done with individual 600/929
# Slice: 0/1. Site: 59. Done with individual 700/929
# Slice: 0/1. Site: 59. Done with individual 800/929
# Slice: 0/1. Site: 59. Done with individual 900/929
# Site index: 60, non ref allele frequency: 0.49917627677100496
# Site index: 60, ref allele frequency: 0.500823723228995
# Check guardrails
# Precentage of valid sites: 0.6533907427341227
# Minor allele frequency: 0.49917627677100496
# Passed guardrails
# Slice: 0/1. Site: 60. Done with individual 0/929
# Slice: 0/1. Site: 60. Done with individual 100/929
# Slice: 0/1. Site: 60. Done with individual 200/929
# Slice: 0/1. Site: 60. Done with individual 300/929
# Slice: 0/1. Site: 60. Done with individual 400/929
# Slice: 0/1. Site: 60. Done with individual 500/929
# Slice: 0/1. Site: 60. Done with individual 600/929
# Slice: 0/1. Site: 60. Done with individual 700/929
# Slice: 0/1. Site: 60. Done with individual 800/929
# Slice: 0/1. Site: 60. Done with individual 900/929
# Site index: 61, non ref allele frequency: 0.502851711026616
# Site index: 61, ref allele frequency: 0.49714828897338403
# Check guardrails
# Precentage of valid sites: 0.566200215285253
# Minor allele frequency: 0.49714828897338403
# Passed guardrails
# Slice: 0/1. Site: 61. Done with individual 0/929
# Slice: 0/1. Site: 61. Done with individual 100/929
# Slice: 0/1. Site: 61. Done with individual 200/929
# Slice: 0/1. Site: 61. Done with individual 300/929
# Slice: 0/1. Site: 61. Done with individual 400/929
# Slice: 0/1. Site: 61. Done with individual 500/929
# Slice: 0/1. Site: 61. Done with individual 600/929
# Slice: 0/1. Site: 61. Done with individual 700/929
# Slice: 0/1. Site: 61. Done with individual 800/929
# Slice: 0/1. Site: 61. Done with individual 900/929
# Site index: 62, non ref allele frequency: 0.4957627118644068
# Site index: 62, ref allele frequency: 0.5042372881355932
# Check guardrails
# Precentage of valid sites: 0.38105489773950485
# Minor allele frequency: 0.4957627118644068
# Passed guardrails
# Slice: 0/1. Site: 62. Done with individual 0/929
# Slice: 0/1. Site: 62. Done with individual 100/929
# Slice: 0/1. Site: 62. Done with individual 200/929
# Slice: 0/1. Site: 62. Done with individual 300/929
# Slice: 0/1. Site: 62. Done with individual 400/929
# Slice: 0/1. Site: 62. Done with individual 500/929
# Slice: 0/1. Site: 62. Done with individual 600/929
# Slice: 0/1. Site: 62. Done with individual 700/929
# Slice: 0/1. Site: 62. Done with individual 800/929
# Slice: 0/1. Site: 62. Done with individual 900/929
# Site index: 63, non ref allele frequency: 0.49019607843137253
# Site index: 63, ref allele frequency: 0.5098039215686274
# Check guardrails
# Precentage of valid sites: 0.10979547900968784
# Minor allele frequency: 0.49019607843137253
# Passed guardrails
# Slice: 0/1. Site: 63. Done with individual 0/929
# Slice: 0/1. Site: 63. Done with individual 100/929
# Slice: 0/1. Site: 63. Done with individual 200/929
# Slice: 0/1. Site: 63. Done with individual 300/929
# Slice: 0/1. Site: 63. Done with individual 400/929
# Slice: 0/1. Site: 63. Done with individual 500/929
# Slice: 0/1. Site: 63. Done with individual 600/929
# Slice: 0/1. Site: 63. Done with individual 700/929
# Slice: 0/1. Site: 63. Done with individual 800/929
# Slice: 0/1. Site: 63. Done with individual 900/929
# Site index: 64, non ref allele frequency: 0.4974025974025974
# Site index: 64, ref allele frequency: 0.5025974025974026
# Check guardrails
# Precentage of valid sites: 0.41442411194833156
# Minor allele frequency: 0.4974025974025974
# Passed guardrails
# Slice: 0/1. Site: 64. Done with individual 0/929
# Slice: 0/1. Site: 64. Done with individual 100/929
# Slice: 0/1. Site: 64. Done with individual 200/929
# Slice: 0/1. Site: 64. Done with individual 300/929
# Slice: 0/1. Site: 64. Done with individual 400/929
# Slice: 0/1. Site: 64. Done with individual 500/929
# Slice: 0/1. Site: 64. Done with individual 600/929
# Slice: 0/1. Site: 64. Done with individual 700/929
# Slice: 0/1. Site: 64. Done with individual 800/929
# Slice: 0/1. Site: 64. Done with individual 900/929
# Site index: 65, non ref allele frequency: 0.49567099567099565
# Site index: 65, ref allele frequency: 0.5043290043290043
# Check guardrails
# ...
# Slice: 1/1. Site: 56. Done with individual 500/929
# Slice: 1/1. Site: 56. Done with individual 600/929
# Slice: 1/1. Site: 56. Done with individual 700/929
# Slice: 1/1. Site: 56. Done with individual 800/929
# Slice: 1/1. Site: 56. Done with individual 900/929
# Site index: 57, non ref allele frequency: 0.5056910569105691
# Site index: 57, ref allele frequency: 0.4943089430894309
# Check guardrails
# Precentage of valid sites: 0.6620021528525296
# Minor allele frequency: 0.4943089430894309
# Passed guardrails
# Slice: 1/1. Site: 57. Done with individual 0/929
# Slice: 1/1. Site: 57. Done with individual 100/929
# Slice: 1/1. Site: 57. Done with individual 200/929
# Slice: 1/1. Site: 57. Done with individual 300/929
# Slice: 1/1. Site: 57. Done with individual 400/929
# Slice: 1/1. Site: 57. Done with individual 500/929
# Slice: 1/1. Site: 57. Done with individual 600/929
# Slice: 1/1. Site: 57. Done with individual 700/929
# Slice: 1/1. Site: 57. Done with individual 800/929
# Slice: 1/1. Site: 57. Done with individual 900/929
# Site index: 58, non ref allele frequency: 0.4916387959866221
# Site index: 58, ref allele frequency: 0.5083612040133779
# Check guardrails
# Precentage of valid sites: 0.3218514531754575
# Minor allele frequency: 0.4916387959866221
# Passed guardrails
# Slice: 1/1. Site: 58. Done with individual 0/929
# Slice: 1/1. Site: 58. Done with individual 100/929
# Slice: 1/1. Site: 58. Done with individual 200/929
# Slice: 1/1. Site: 58. Done with individual 300/929
# Slice: 1/1. Site: 58. Done with individual 400/929
# Slice: 1/1. Site: 58. Done with individual 500/929
# Slice: 1/1. Site: 58. Done with individual 600/929
# Slice: 1/1. Site: 58. Done with individual 700/929
# Slice: 1/1. Site: 58. Done with individual 800/929
# Slice: 1/1. Site: 58. Done with individual 900/929
# Site index: 59, non ref allele frequency: 0.5057660626029654
# Site index: 59, ref allele frequency: 0.4942339373970346
# Check guardrails
# Precentage of valid sites: 0.6533907427341227
# Minor allele frequency: 0.4942339373970346
# Passed guardrails
# Slice: 1/1. Site: 59. Done with individual 0/929
# Slice: 1/1. Site: 59. Done with individual 100/929
# Slice: 1/1. Site: 59. Done with individual 200/929
# Slice: 1/1. Site: 59. Done with individual 300/929
# Slice: 1/1. Site: 59. Done with individual 400/929
# Slice: 1/1. Site: 59. Done with individual 500/929
# Slice: 1/1. Site: 59. Done with individual 600/929
# Slice: 1/1. Site: 59. Done with individual 700/929
# Slice: 1/1. Site: 59. Done with individual 800/929
# Slice: 1/1. Site: 59. Done with individual 900/929
# Site index: 60, non ref allele frequency: 0.5068285280728376
# Site index: 60, ref allele frequency: 0.4931714719271624
# Check guardrails
# Precentage of valid sites: 0.7093649085037675
# Minor allele frequency: 0.4931714719271624
# Passed guardrails
# Slice: 1/1. Site: 60. Done with individual 0/929
# Slice: 1/1. Site: 60. Done with individual 100/929
# Slice: 1/1. Site: 60. Done with individual 200/929
# Slice: 1/1. Site: 60. Done with individual 300/929
# Slice: 1/1. Site: 60. Done with individual 400/929
# Slice: 1/1. Site: 60. Done with individual 500/929
# Slice: 1/1. Site: 60. Done with individual 600/929
# Slice: 1/1. Site: 60. Done with individual 700/929
# Slice: 1/1. Site: 60. Done with individual 800/929
# Slice: 1/1. Site: 60. Done with individual 900/929
# Site index: 61, non ref allele frequency: 0.49117647058823527
# Site index: 61, ref allele frequency: 0.5088235294117647
# Check guardrails
# Precentage of valid sites: 0.7319698600645855
# Minor allele frequency: 0.49117647058823527
# Passed guardrails
# Slice: 1/1. Site: 61. Done with individual 0/929
# Slice: 1/1. Site: 61. Done with individual 100/929
# Slice: 1/1. Site: 61. Done with individual 200/929
# Slice: 1/1. Site: 61. Done with individual 300/929
# Slice: 1/1. Site: 61. Done with individual 400/929
# Slice: 1/1. Site: 61. Done with individual 500/929
# Slice: 1/1. Site: 61. Done with individual 600/929
# Slice: 1/1. Site: 61. Done with individual 700/929
# Slice: 1/1. Site: 61. Done with individual 800/929
# Slice: 1/1. Site: 61. Done with individual 900/929
# Site index: 62, non ref allele frequency: 0.5
# Site index: 62, ref allele frequency: 0.5
# Check guardrails
# Precentage of valid sites: 0.7308934337997847
# Minor allele frequency: 0.5
# Passed guardrails
# Slice: 1/1. Site: 62. Done with individual 0/929
# Slice: 1/1. Site: 62. Done with individual 100/929
# Slice: 1/1. Site: 62. Done with individual 200/929
# Slice: 1/1. Site: 62. Done with individual 300/929
# Slice: 1/1. Site: 62. Done with individual 400/929
# Slice: 1/1. Site: 62. Done with individual 500/929
# Slice: 1/1. Site: 62. Done with individual 600/929
# Slice: 1/1. Site: 62. Done with individual 700/929
# Slice: 1/1. Site: 62. Done with individual 800/929
# Slice: 1/1. Site: 62. Done with individual 900/929
# Site index: 63, non ref allele frequency: 0.5080775444264943
# Site index: 63, ref allele frequency: 0.49192245557350567
# Check guardrails
# Precentage of valid sites: 0.6663078579117331
# Minor allele frequency: 0.49192245557350567
# Passed guardrails
# Slice: 1/1. Site: 63. Done with individual 0/929
# Slice: 1/1. Site: 63. Done with individual 100/929
# Slice: 1/1. Site: 63. Done with individual 200/929
# Slice: 1/1. Site: 63. Done with individual 300/929
# Slice: 1/1. Site: 63. Done with individual 400/929
# Slice: 1/1. Site: 63. Done with individual 500/929
# Slice: 1/1. Site: 63. Done with individual 600/929
# Slice: 1/1. Site: 63. Done with individual 700/929
# Slice: 1/1. Site: 63. Done with individual 800/929
# Slice: 1/1. Site: 63. Done with individual 900/929
# Site index: 64, non ref allele frequency: 0.49323181049069376
# Site index: 64, ref allele frequency: 0.5067681895093062
# Check guardrails
# Precentage of valid sites: 0.6361679224973089
# Minor allele frequency: 0.49323181049069376
# Passed guardrails
# Slice: 1/1. Site: 64. Done with individual 0/929
# Slice: 1/1. Site: 64. Done with individual 100/929
# Slice: 1/1. Site: 64. Done with individual 200/929
# Slice: 1/1. Site: 64. Done with individual 300/929
# Slice: 1/1. Site: 64. Done with individual 400/929
# Slice: 1/1. Site: 64. Done with individual 500/929
# Slice: 1/1. Site: 64. Done with individual 600/929
# Slice: 1/1. Site: 64. Done with individual 700/929
# Slice: 1/1. Site: 64. Done with individual 800/929
# Slice: 1/1. Site: 64. Done with individual 900/929
# Site index: 65, non ref allele frequency: 0.49455676516329705
# Site index: 65, ref allele frequency: 0.505443234836703
# Check guardrails
# Precentage of valid sites: 0.6921420882669537
# Minor allele frequency: 0.49455676516329705
# Passed guardrails
# Slice: 1/1. Site: 65. Done with individual 0/929
# Slice: 1/1. Site: 65. Done with individual 100/929
# Slice: 1/1. Site: 65. Done with individual 200/929
# Slice: 1/1. Site: 65. Done with individual 300/929
# Slice: 1/1. Site: 65. Done with individual 400/929
# Slice: 1/1. Site: 65. Done with individual 500/929
# Slice: 1/1. Site: 65. Done with individual 600/929
# Slice: 1/1. Site: 65. Done with individual 700/929
# Slice: 1/1. Site: 65. Done with individual 800/929
# Slice: 1/1. Site: 65. Done with individual 900/929
# Site index: 66, non ref allele frequency: 0.5083932853717026
# Site index: 66, ref allele frequency: 0.49160671462829736
# Check guardrails
# Precentage of valid sites: 0.4488697524219591
# Minor allele frequency: 0.49160671462829736
# Passed guardrails
# Slice: 1/1. Site: 66. Done with individual 0/929
# Slice: 1/1. Site: 66. Done with individual 100/929
# Slice: 1/1. Site: 66. Done with individual 200/929
# Slice: 1/1. Site: 66. Done with individual 300/929
# Slice: 1/1. Site: 66. Done with individual 400/929
# Slice: 1/1. Site: 66. Done with individual 500/929
# Slice: 1/1. Site: 66. Done with individual 600/929
# Slice: 1/1. Site: 66. Done with individual 700/929
# Slice: 1/1. Site: 66. Done with individual 800/929
# Slice: 1/1. Site: 66. Done with individual 900/929
# Site index: 67, non ref allele frequency: 0.49796747967479676
# Site index: 67, ref allele frequency: 0.5020325203252033
# Check guardrails
# Precentage of valid sites: 0.26480086114101187
# Minor allele frequency: 0.49796747967479676
# Passed guardrails
# Slice: 1/1. Site: 67. Done with individual 0/929
# Slice: 1/1. Site: 67. Done with individual 100/929
# Slice: 1/1. Site: 67. Done with individual 200/929
# Slice: 1/1. Site: 67. Done with individual 300/929
# Slice: 1/1. Site: 67. Done with individual 400/929
# Slice: 1/1. Site: 67. Done with individual 500/929
# Slice: 1/1. Site: 67. Done with individual 600/929
# Slice: 1/1. Site: 67. Done with individual 700/929
# Slice: 1/1. Site: 67. Done with individual 800/929
# Slice: 1/1. Site: 67. Done with individual 900/929
# Site index: 68, non ref allele frequency: 0.49843014128728413
# Site index: 68, ref allele frequency: 0.5015698587127159
# Check guardrails
# Precentage of valid sites: 0.6856835306781486
# Minor allele frequency: 0.49843014128728413
# Passed guardrails
# Slice: 1/1. Site: 68. Done with individual 0/929
# Slice: 1/1. Site: 68. Done with individual 100/929
# Slice: 1/1. Site: 68. Done with individual 200/929
# Slice: 1/1. Site: 68. Done with individual 300/929
# Slice: 1/1. Site: 68. Done with individual 400/929
# Slice: 1/1. Site: 68. Done with individual 500/929
# Slice: 1/1. Site: 68. Done with individual 600/929
# Slice: 1/1. Site: 68. Done with individual 700/929
# Slice: 1/1. Site: 68. Done with individual 800/929
# Slice: 1/1. Site: 68. Done with individual 900/929
# Site index: 69, non ref allele frequency: 0.5068807339449541
# Site index: 69, ref allele frequency: 0.49311926605504586
# Check guardrails
# Precentage of valid sites: 0.7039827771797632
# Minor allele frequency: 0.49311926605504586
# Passed guardrails
# Slice: 1/1. Site: 69. Done with individual 0/929
# Slice: 1/1. Site: 69. Done with individual 100/929
# Slice: 1/1. Site: 69. Done with individual 200/929
# Slice: 1/1. Site: 69. Done with individual 300/929
# Slice: 1/1. Site: 69. Done with individual 400/929
# Slice: 1/1. Site: 69. Done with individual 500/929
# Slice: 1/1. Site: 69. Done with individual 600/929
# Slice: 1/1. Site: 69. Done with individual 700/929
# Slice: 1/1. Site: 69. Done with individual 800/929
# Slice: 1/1. Site: 69. Done with individual 900/929
# Site index: 70, non ref allele frequency: 0.5038167938931297
# Site index: 70, ref allele frequency: 0.4961832061068702
# Check guardrails
# Precentage of valid sites: 0.7050592034445641
# Minor allele frequency: 0.4961832061068702
# Passed guardrails
# Slice: 1/1. Site: 70. Done with individual 0/929
# Slice: 1/1. Site: 70. Done with individual 100/929
# Slice: 1/1. Site: 70. Done with individual 200/929
# Slice: 1/1. Site: 70. Done with individual 300/929
# Slice: 1/1. Site: 70. Done with individual 400/929
# Slice: 1/1. Site: 70. Done with individual 500/929
# Slice: 1/1. Site: 70. Done with individual 600/929
# Slice: 1/1. Site: 70. Done with individual 700/929
# Slice: 1/1. Site: 70. Done with individual 800/929
# Slice: 1/1. Site: 70. Done with individual 900/929
# Site index: 71, non ref allele frequency: 0.506872852233677
# Site index: 71, ref allele frequency: 0.49312714776632305
# Check guardrails
# Precentage of valid sites: 0.3132400430570506
# Minor allele frequency: 0.49312714776632305
# Passed guardrails
# Slice: 1/1. Site: 71. Done with individual 0/929
# Slice: 1/1. Site: 71. Done with individual 100/929
# Slice: 1/1. Site: 71. Done with individual 200/929
# Slice: 1/1. Site: 71. Done with individual 300/929
# Slice: 1/1. Site: 71. Done with individual 400/929
# Slice: 1/1. Site: 71. Done with individual 500/929
# Slice: 1/1. Site: 71. Done with individual 600/929
# Slice: 1/1. Site: 71. Done with individual 700/929
# Slice: 1/1. Site: 71. Done with individual 800/929
# Slice: 1/1. Site: 71. Done with individual 900/929
# Site index: 72, non ref allele frequency: 0.491869918699187
# Site index: 72, ref allele frequency: 0.508130081300813
# Check guardrails
# Precentage of valid sites: 0.5296017222820237
# Minor allele frequency: 0.491869918699187
# Passed guardrails
# Slice: 1/1. Site: 72. Done with individual 0/929
# Slice: 1/1. Site: 72. Done with individual 100/929
# Slice: 1/1. Site: 72. Done with individual 200/929
# Slice: 1/1. Site: 72. Done with individual 300/929
# Slice: 1/1. Site: 72. Done with individual 400/929
# Slice: 1/1. Site: 72. Done with individual 500/929
# Slice: 1/1. Site: 72. Done with individual 600/929
# Slice: 1/1. Site: 72. Done with individual 700/929
# Slice: 1/1. Site: 72. Done with individual 800/929
# Slice: 1/1. Site: 72. Done with individual 900/929
# Site index: 73, non ref allele frequency: 0.5032679738562091
# Site index: 73, ref allele frequency: 0.49673202614379086
# Check guardrails
# Precentage of valid sites: 0.4940796555435953
# Minor allele frequency: 0.49673202614379086
# Passed guardrails
# Slice: 1/1. Site: 73. Done with individual 0/929
# Slice: 1/1. Site: 73. Done with individual 100/929
# Slice: 1/1. Site: 73. Done with individual 200/929
# Slice: 1/1. Site: 73. Done with individual 300/929
# Slice: 1/1. Site: 73. Done with individual 400/929
# Slice: 1/1. Site: 73. Done with individual 500/929
# Slice: 1/1. Site: 73. Done with individual 600/929
# Slice: 1/1. Site: 73. Done with individual 700/929
# Slice: 1/1. Site: 73. Done with individual 800/929
# Slice: 1/1. Site: 73. Done with individual 900/929
# Site index: 74, non ref allele frequency: 0.4954682779456193
# Site index: 74, ref allele frequency: 0.5045317220543807
# Check guardrails
# Precentage of valid sites: 0.71259418729817
# Minor allele frequency: 0.4954682779456193
# Passed guardrails
# Slice: 1/1. Site: 74. Done with individual 0/929
# Slice: 1/1. Site: 74. Done with individual 100/929
# Slice: 1/1. Site: 74. Done with individual 200/929
# Slice: 1/1. Site: 74. Done with individual 300/929
# Slice: 1/1. Site: 74. Done with individual 400/929
# Slice: 1/1. Site: 74. Done with individual 500/929
# Slice: 1/1. Site: 74. Done with individual 600/929
# Slice: 1/1. Site: 74. Done with individual 700/929
# Slice: 1/1. Site: 74. Done with individual 800/929
# Slice: 1/1. Site: 74. Done with individual 900/929
# Site index: 75, non ref allele frequency: 0.5019342359767892
# Site index: 75, ref allele frequency: 0.49806576402321084
# Check guardrails
# Precentage of valid sites: 0.5565123789020452
# Minor allele frequency: 0.49806576402321084
# Passed guardrails
# Slice: 1/1. Site: 75. Done with individual 0/929
# Slice: 1/1. Site: 75. Done with individual 100/929
# Slice: 1/1. Site: 75. Done with individual 200/929
# Slice: 1/1. Site: 75. Done with individual 300/929
# Slice: 1/1. Site: 75. Done with individual 400/929
# Slice: 1/1. Site: 75. Done with individual 500/929
# Slice: 1/1. Site: 75. Done with individual 600/929
# Slice: 1/1. Site: 75. Done with individual 700/929
# Slice: 1/1. Site: 75. Done with individual 800/929
# Slice: 1/1. Site: 75. Done with individual 900/929
# Site index: 76, non ref allele frequency: 0.4972477064220184
# Site index: 76, ref allele frequency: 0.5027522935779817
# Check guardrails
# Precentage of valid sites: 0.5866523143164694
# Minor allele frequency: 0.4972477064220184
# Passed guardrails
# Slice: 1/1. Site: 76. Done with individual 0/929
# Slice: 1/1. Site: 76. Done with individual 100/929
# Slice: 1/1. Site: 76. Done with individual 200/929
# Slice: 1/1. Site: 76. Done with individual 300/929
# Slice: 1/1. Site: 76. Done with individual 400/929
# Slice: 1/1. Site: 76. Done with individual 500/929
# Slice: 1/1. Site: 76. Done with individual 600/929
# Slice: 1/1. Site: 76. Done with individual 700/929
# Slice: 1/1. Site: 76. Done with individual 800/929
# Slice: 1/1. Site: 76. Done with individual 900/929
# Site index: 77, non ref allele frequency: 0.5047619047619047
# Site index: 77, ref allele frequency: 0.49523809523809526
# Check guardrails
# Precentage of valid sites: 0.5651237890204521
# Minor allele frequency: 0.49523809523809526
# Passed guardrails
# Slice: 1/1. Site: 77. Done with individual 0/929
# Slice: 1/1. Site: 77. Done with individual 100/929
# Slice: 1/1. Site: 77. Done with individual 200/929
# Slice: 1/1. Site: 77. Done with individual 300/929
# Slice: 1/1. Site: 77. Done with individual 400/929
# Slice: 1/1. Site: 77. Done with individual 500/929
# Slice: 1/1. Site: 77. Done with individual 600/929
# Slice: 1/1. Site: 77. Done with individual 700/929
# Slice: 1/1. Site: 77. Done with individual 800/929
# Slice: 1/1. Site: 77. Done with individual 900/929
# todo

# %%
s = 'vcftools --gzvcf vcf_file --out output_folder --max-alleles 2 --min-alleles 2 --freq2'
print (s.split())
# Out:
# ['vcftools', '--gzvcf', 'vcf_file', '--out', 'output_folder', '--max-alleles', '2', '--min-alleles', '2', '--freq2']

# %%
for i in range(21):
    print('chr'+str(i))
# Out:
# chr0
# chr1
# chr2
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chr10
# chr11
# chr12
# chr13
# chr14
# chr15
# chr16
# chr17
# chr18
# chr19
# chr20
